# %%
import http.client
import json
from tqdm import tqdm

# %%
import http.client

conn = http.client.HTTPSConnection("www.jarir.com")

payload = ""

headers = { 'cookie': "__cf_bm=Yi9c62OSBgXrB_plPFgV.UvamLouXzgGSaEcZdb9qIg-1663145002-0-AWnPBFBeMJQOhDHBO7px%2BSfdfqJwqW0zFiwlbrcRmxT%2BAMIdFwS5GYDt9s7t6fmM8CIubU1OV2sC9ekxJgaH0Vo%3D" }
pagelode=["12","24","36"]
import json
list_prices = []
BASE_URL = "/api/catalogv1/product/store/sa-ar/category_ids/1008/aggregation/true/size/12/from/{}/sort-priority/asc"

list_prices = []
list_error_items = []
list_ids = []
init_page = 12

for _ in tqdm(range(90)):
    conn.request(f"GET", BASE_URL.format(init_page), payload, headers)
    res = conn.getresponse()
    data = res.read()
    responseObject = json.loads(data)['hits']['hits']
    for product in responseObject:
        if product['_source']['id'] not in list_ids:
            try:
                list_prices.append({
                    'before':product['_source']['price'],
                    'special_price':product['_source']['special_price'],
                    'after': product['_source']['final_price_ex_tax'],
                    'name':product['_source']['seri'],
                    'capcity_GB':product['_source']['arabicname_field3'],
                    'RAM':product['_source']['arabicname_field4'],
                    'processer':product['_source']['arabicname_field6'],
                    'Colour':product['_source']['arabicname_field7'],
                    'model':product['_source']['model'],
                    'meta_keyword':product['_source']['meta_keyword']
                })
                list_ids.append(product['_source']['id'])
            except:
                list_error_items.append({
                    'link':BASE_URL,
                    'object': product
                })
    init_page +=12

list_prices
# Out:
# 100%|██████████| 90/90 [00:36<00:00,  2.45it/s]
# [{'before': 6799,
#   'special_price': 5699,
#   'after': 4955.6522,
#   'name': 'سامسونج) جالكسي زد)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e12 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 888 5 جي\u200e',
#   'Colour': '\u200eاخضر\u200e',
#   'model': '\u200eجالكسي زد فولد 3\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي زد),SMF926BZGDMEA,سعة 256 جيجابايت,اخضر,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3999,
#   'special_price': 2899,
#   'after': 2520.8696,
#   'name': 'سامسونج) جالكسي زد)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eاخضر\u200e',
#   'Colour': None,
#   'model': '\u200eجالكسي زد فليب 3\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي زد),SMF711BZGFMEA,سعة 256 جيجابايت,اخضر,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3999,
#   'special_price': 2899,
#   'after': 2520.8696,
#   'name': 'سامسونج) جالكسي زد)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eاسود\u200e',
#   'Colour': None,
#   'model': '\u200eجالكسي زد فليب 3\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي زد),SMF711BZKFMEA,سعة 256 جيجابايت,اسود,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 5299,
#   'special_price': 4299,
#   'after': 3738.2609,
#   'name': 'هواوي) بي)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 888\u200e',
#   'Colour': '\u200e ابيض\u200e',
#   'model': '\u200eبي 50 بوكت\u200e',
#   'meta_keyword': 'هواوي,هواوي) بي),51096WVX,سعة 256 جيجابايت, ابيض,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2999,
#   'special_price': 2249,
#   'after': 1955.6522,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eاكسينوس  2100\u200e',
#   'Colour': '\u200eأخضر فاتح\u200e',
#   'model': '\u200eجالكسي اس 21 اف اي \u200e5\u200eG\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMG990ELGGMEA,سعة 256 جيجابايت,اخضر فاتح,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2999,
#   'special_price': 2249,
#   'after': 1955.6522,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eاكسينوس  2100\u200e',
#   'Colour': '\u200eبنفسجي فاتح\u200e',
#   'model': '\u200eجالكسي اس 21 اف اي \u200e5\u200eG\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMG990ELVGMEA,سعة 256 جيجابايت,بنفسجي فاتح,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2999,
#   'special_price': 2249,
#   'after': 1955.6522,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eاكسينوس  2100\u200e',
#   'Colour': '\u200e ابيض\u200e',
#   'model': '\u200eجالكسي اس 21 اف اي \u200e5\u200eG\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMG990EZWGMEA,سعة 256 جيجابايت, ابيض,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1699,
#   'special_price': 1599,
#   'after': 1390.4348,
#   'name': 'شاومي سلسلة بوكو فون',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 870\u200e',
#   'Colour': '\u200eأسود ليلي\u200e',
#   'model': '\u200eبوكو اف 4 5 جي\u200e',
#   'meta_keyword': 'Xiaomi,شاومي سلسلة بوكو فون,MZB0BOAEN,سعة 256 جيجابايت,أسود ليلي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1699,
#   'special_price': 1599,
#   'after': 1390.4348,
#   'name': 'شاومي سلسلة بوكو فون',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 870\u200e',
#   'Colour': '\u200eNebula Green\u200e',
#   'model': '\u200eبوكو اف 4 5 جي\u200e',
#   'meta_keyword': 'Xiaomi,شاومي سلسلة بوكو فون,MZB0BO8EN,سعة 256 جيجابايت,,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1699,
#   'special_price': 1599,
#   'after': 1390.4348,
#   'name': 'شاومي سلسلة بوكو فون',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 870\u200e',
#   'Colour': '\u200eفضية ضوء القمر\u200e',
#   'model': '\u200eبوكو اف 4 5 جي\u200e',
#   'meta_keyword': 'Xiaomi,شاومي سلسلة بوكو فون,MZB0BN6EN,سعة 256 جيجابايت,فضية ضوء القمر,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2999,
#   'special_price': 2249,
#   'after': 1955.6522,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eاكسينوس  2100\u200e',
#   'Colour': '\u200eرمادي\u200e',
#   'model': '\u200eجالكسي اس 21 اف اي \u200e5\u200eG\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMG990EZAGMEA,سعة 256 جيجابايت,رمادي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2799,
#   'special_price': 1999,
#   'after': 1738.2609,
#   'name': 'أوبو رينو',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e12 جيجابايت رام\u200e',
#   'processer': '\u200eأسود\u200e',
#   'Colour': None,
#   'model': '\u200eرينو 5 برو\u200e',
#   'meta_keyword': 'أوبو,أوبو رينو,CPH2207BLK,سعة 256 جيجابايت,أسود,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2499,
#   'special_price': 1699,
#   'after': 1477.3913,
#   'name': 'هونر سلسلة 50',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 778 جي\u200e',
#   'Colour': '\u200eأسود منتصف الليل\u200e',
#   'model': '50',
#   'meta_keyword': 'هونر,هونر سلسلة 50,5109ABBM,سعة 256 جيجابايت,أسود منتصف الليل,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2499,
#   'special_price': 1699,
#   'after': 1477.3913,
#   'name': 'هونر سلسلة 50',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 778 جي\u200e',
#   'Colour': '\u200eلون الكريستال الصقيع\u200e',
#   'model': '50',
#   'meta_keyword': 'هونر,هونر سلسلة 50,5109ABBR,سعة 256 جيجابايت,لون الكريستال الصقيع,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2499,
#   'special_price': 1699,
#   'after': 1477.3913,
#   'name': 'هونر سلسلة 50',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 778 جي\u200e',
#   'Colour': '\u200eأخضر زمردي\u200e',
#   'model': '50',
#   'meta_keyword': 'هونر,هونر سلسلة 50,5109ABBV,سعة 256 جيجابايت,أخضر زمردي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1899,
#   'special_price': 1199,
#   'after': 1042.6087,
#   'name': '(Huawei) nova',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200e4\u200eG LTE\u200e',
#   'Colour': '\u200eكوالكوم سناب دراغون 778 جي\u200e',
#   'model': '\u200eنوفا 9\u200e',
#   'meta_keyword': 'هواوي,هواوي) نوفا),51096UGT,سعة 128 جيجابايت,نجمة ازرق,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1899,
#   'special_price': 1199,
#   'after': 1042.6087,
#   'name': '(Huawei) nova',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 778 جي\u200e',
#   'Colour': '\u200eاسود\u200e',
#   'model': '\u200eنوفا 9\u200e',
#   'meta_keyword': 'هواوي,هواوي) نوفا),51096UGV,سعة 128 جيجابايت,اسود,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2999,
#   'special_price': 2399,
#   'after': 2086.087,
#   'name': 'أوبو رينو',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e12 جيجابايت رام\u200e',
#   'processer': '\u200eثلجي الازرق\u200e',
#   'Colour': None,
#   'model': '\u200eرينو 6 برو\u200e',
#   'meta_keyword': 'أوبو,أوبو رينو,CPH2247BLU,سعة 256 جيجابايت,ثلجي الازرق,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2999,
#   'special_price': 2399,
#   'after': 2086.087,
#   'name': 'أوبو رينو',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e12 جيجابايت رام\u200e',
#   'processer': '\u200eرمادي قمري\u200e',
#   'Colour': None,
#   'model': '\u200eرينو 6 برو\u200e',
#   'meta_keyword': 'أوبو,أوبو رينو,CPH2247GRY,سعة 256 جيجابايت,رمادي قمري,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2999,
#   'special_price': 2399,
#   'after': 2086.087,
#   'name': 'هواوي) بي)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 888\u200e',
#   'Colour': '\u200eذهبي أسود\u200e',
#   'model': 'P50',
#   'meta_keyword': 'هواوي,هواوي) بي),51097DCN,سعة 256 جيجابايت,ذهبي أسود,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2999,
#   'special_price': 2399,
#   'after': 2086.087,
#   'name': 'هواوي) بي)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 888\u200e',
#   'Colour': '\u200eذهب كاكاو\u200e',
#   'model': 'P50',
#   'meta_keyword': 'هواوي,هواوي) بي),51097DCQ,سعة 256 جيجابايت,ذهب كاكاو,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3949,
#   'special_price': 3499,
#   'after': 3042.6087,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eاخضر\u200e',
#   'model': '\u200e جالكسي اس 22 بلس\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS906EZGDMEA,سعة 128 جيجابايت,اخضر,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3949,
#   'special_price': 3499,
#   'after': 3042.6087,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eذهبي وردي\u200e',
#   'model': '\u200e جالكسي اس 22 بلس\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS906EIDDMEA,سعة 128 جيجابايت,ذهبي وردي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3949,
#   'special_price': 3499,
#   'after': 3042.6087,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eأسود فانتوم\u200e',
#   'model': '\u200e جالكسي اس 22 بلس\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS906EZKDMEA,سعة 128 جيجابايت,أسود فانتوم,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3949,
#   'special_price': 3499,
#   'after': 3042.6087,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eأبيض فانتوم\u200e',
#   'model': '\u200e جالكسي اس 22 بلس\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS906EZWDMEA,سعة 128 جيجابايت,أبيض فانتوم,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3499,
#   'special_price': 3099,
#   'after': 2694.7826,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200e5\u200eG\u200e',
#   'Colour': '\u200eكوالكوم سناب دراغون 8\u200e',
#   'model': '\u200eجالكسي اس 22\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS901EZKGMEA,سعة 256 جيجابايت,أسود فانتوم,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3499,
#   'special_price': 3099,
#   'after': 2694.7826,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200e5\u200eG\u200e',
#   'Colour': '\u200eكوالكوم سناب دراغون 8\u200e',
#   'model': '\u200eجالكسي اس 22\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS901EZGGMEA,سعة 256 جيجابايت,اخضر,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3499,
#   'special_price': 3099,
#   'after': 2694.7826,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eذهبي وردي\u200e',
#   'model': '\u200eجالكسي اس 22\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS901EIDGMEA,سعة 256 جيجابايت,ذهبي وردي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3499,
#   'special_price': 3099,
#   'after': 2694.7826,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eأبيض فانتوم\u200e',
#   'model': '\u200eجالكسي اس 22\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS901EZWGMEA,سعة 256 جيجابايت,أبيض فانتوم,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3499,
#   'special_price': 3099,
#   'after': 2694.7826,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eبورا البنفسجي\u200e',
#   'model': '\u200eجالكسي اس 22\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS901ELVGMEA,سعة 256 جيجابايت,,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1659,
#   'special_price': 1299,
#   'after': 1129.5652,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم MSM7325\u200e\u200e',
#   'Colour': '\u200eأخضر فاتح\u200e',
#   'model': '\u200eجالكسي ايه52 اس 5 جي\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA528BLGOMEA,سعة 128 جيجابايت,اخضر فاتح,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1659,
#   'special_price': 1299,
#   'after': 1129.5652,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم MSM7325\u200e\u200e',
#   'Colour': '\u200eبنفسجي فاتح\u200e',
#   'model': '\u200eجالكسي ايه52 اس 5 جي\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA528BLVOMEA,سعة 128 جيجابايت,بنفسجي فاتح,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1659,
#   'special_price': 1299,
#   'after': 1129.5652,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200e5\u200eG\u200e',
#   'Colour': '\u200eكوالكوم MSM7325\u200e\u200e',
#   'model': '\u200eجالكسي ايه52 اس 5 جي\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA528BZWOMEA,سعة 128 جيجابايت, ابيض,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1659,
#   'special_price': 1299,
#   'after': 1129.5652,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم MSM7325\u200e\u200e',
#   'Colour': '\u200eاسود\u200e',
#   'model': '\u200eجالكسي ايه52 اس 5 جي\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA528BZKOMEA,سعة 128 جيجابايت,اسود,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 4149,
#   'special_price': 3799,
#   'after': 3303.4783,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eذهبي وردي\u200e',
#   'model': '\u200e جالكسي اس 22 بلس\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS906EIDGMEA,سعة 256 جيجابايت,ذهبي وردي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 4149,
#   'special_price': 3799,
#   'after': 3303.4783,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eأبيض فانتوم\u200e',
#   'Colour': None,
#   'model': '\u200e جالكسي اس 22 بلس\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS906EZWGMEA,سعة 256 جيجابايت,أبيض فانتوم,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1199,
#   'special_price': 849,
#   'after': 738.2609,
#   'name': '(Nokia) X',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200e+ كوالكوم سناب دراغون 480\u200e',
#   'Colour': '\u200eنورديك الازرق\u200e',
#   'model': 'X20',
#   'meta_keyword': 'نوكيا,,101QKSLVH043,سعة 128 جيجابايت,نورديك الازرق,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 4149,
#   'special_price': 3799,
#   'after': 3303.4783,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eاخضر\u200e',
#   'Colour': None,
#   'model': '\u200e جالكسي اس 22 بلس\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS906EZGGMEA,سعة 256 جيجابايت,اخضر,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 4149,
#   'special_price': 3799,
#   'after': 3303.4783,
#   'name': ' سامسونج) جالكسي أس)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eأسود فانتوم\u200e',
#   'model': '\u200e جالكسي اس 22 بلس\u200e',
#   'meta_keyword': 'سامسونج, سامسونج) جالكسي أس),SMS906EZKGMEA,سعة 256 جيجابايت,أسود فانتوم,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 7299,
#   'special_price': 6999,
#   'after': 6086.087,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eلون أزرق سيريا\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200e ايفون 13 برو ماكس\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLKK3AHA,سعة 1 تيرا بايت,لون أزرق سيريا,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1499,
#   'special_price': 1199,
#   'after': 1042.6087,
#   'name': 'أوبو رينو',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eDimensity \u200e800\u200eU\u200e',
#   'Colour': '\u200eأورورا\u200e',
#   'model': '\u200eرينو \u200e6\u200ez\u200e',
#   'meta_keyword': 'أوبو,أوبو رينو,CPH2237BLU,سعة 128 جيجابايت,أورورا,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 7299,
#   'special_price': 6999,
#   'after': 6086.087,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eفضي\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200e ايفون 13 برو ماكس\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLKH3AHA,سعة 1 تيرا بايت,فضي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 7299,
#   'special_price': 6999,
#   'after': 6086.087,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eذهبي\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200e ايفون 13 برو ماكس\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLKJ3AHA,سعة 1 تيرا بايت,ذهبي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1499,
#   'special_price': 1199,
#   'after': 1042.6087,
#   'name': 'أوبو رينو',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eDimensity \u200e800\u200eU\u200e',
#   'Colour': '\u200eممتاز أسود\u200e',
#   'model': '\u200eرينو \u200e6\u200ez\u200e',
#   'meta_keyword': 'أوبو,أوبو رينو,CPH2237BLK,سعة 128 جيجابايت,ممتاز أسود,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1799,
#   'special_price': 1599,
#   'after': 1390.4348,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eاسود\u200e',
#   'Colour': None,
#   'model': '\u200eجالكسي ايه53\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA536EZKHMEA,سعة 256 جيجابايت,اسود,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1599,
#   'special_price': 1399,
#   'after': 1216.5217,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eاسود\u200e',
#   'Colour': None,
#   'model': '\u200eجالكسي ايه53\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA536EZKGMEA,سعة 128 جيجابايت,اسود,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1599,
#   'special_price': 1399,
#   'after': 1216.5217,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eبرتقالي\u200e',
#   'Colour': None,
#   'model': '\u200eجالكسي ايه53\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA536EZOGMEA,سعة 128 جيجابايت,برتقالي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1599,
#   'special_price': 1399,
#   'after': 1216.5217,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eأزرق لايتنينج\u200e',
#   'Colour': None,
#   'model': '\u200eجالكسي ايه53\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA536ELBGMEA,سعة 128 جيجابايت,أزرق لايتنينج,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1799,
#   'special_price': 1599,
#   'after': 1390.4348,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200e ابيض\u200e',
#   'Colour': None,
#   'model': '\u200eجالكسي ايه53\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA536EZWHMEA,سعة 256 جيجابايت, ابيض,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1599,
#   'special_price': 1399,
#   'after': 1216.5217,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200e ابيض\u200e',
#   'Colour': None,
#   'model': '\u200eجالكسي ايه53\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA536EZWGMEA,سعة 128 جيجابايت, ابيض,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1799,
#   'special_price': 1599,
#   'after': 1390.4348,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eبرتقالي\u200e',
#   'Colour': None,
#   'model': '\u200eجالكسي ايه53\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA536EZOHMEA,سعة 256 جيجابايت,برتقالي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1799,
#   'special_price': 1599,
#   'after': 1390.4348,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eأزرق فاتح\u200e',
#   'Colour': None,
#   'model': '\u200eجالكسي ايه53\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA536ELBHMEA,سعة 256 جيجابايت,ازرق فاتح,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3299,
#   'special_price': 3049,
#   'after': 2651.3043,
#   'name': 'آبل) ايفون 12)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eازرق\u200e',
#   'processer': "\u200e'                                                            أبل ايه14 بايونيك\u200e",
#   'Colour': None,
#   'model': '\u200eايفون 12\u200e',
#   'meta_keyword': 'ابل,آبل) ايفون 12),MGJE3AAA,سعة 128 جيجابايت,ازرق,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3299,
#   'special_price': 3049,
#   'after': 2651.3043,
#   'name': 'آبل) ايفون 12)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eاسود\u200e',
#   'processer': "\u200e'                                                            أبل ايه14 بايونيك\u200e",
#   'Colour': None,
#   'model': '\u200eايفون 12\u200e',
#   'meta_keyword': 'ابل,آبل) ايفون 12),MGJA3AAA,سعة 128 جيجابايت,اسود,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1199,
#   'special_price': 949,
#   'after': 825.2174,
#   'name': '(Huawei) nova',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 680 6 nm\u200e',
#   'Colour': '\u200eالكريستال الازرق\u200e',
#   'model': '\u200eنوفا 9 SE\u200e',
#   'meta_keyword': 'هواوي,هواوي) نوفا),51096XGM,سعة 128 جيجابايت,الكريستال الازرق,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1699,
#   'special_price': 1449,
#   'after': 1260,
#   'name': 'موتورولا) ايدج)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200e5\u200eG\u200e',
#   'Colour': '\u200eكوالكوم سناب دراغون 778 جي\u200e',
#   'model': '\u200eادج 30\u200e',
#   'meta_keyword': 'موتورولا,موتورولا) ايدج),PAUC0038AE,سعة 256 جيجابايت,,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1699,
#   'special_price': 1449,
#   'after': 1260,
#   'name': 'موتورولا) ايدج)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200e5\u200eG\u200e',
#   'Colour': '\u200eكوالكوم سناب دراغون 778 جي\u200e',
#   'model': '\u200eادج 30\u200e',
#   'meta_keyword': 'موتورولا,موتورولا) ايدج),PAUC0045AE,سعة 256 جيجابايت,أخضر أورورا,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1199,
#   'special_price': 949,
#   'after': 825.2174,
#   'name': '(Huawei) nova',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 680 6 nm\u200e',
#   'Colour': '\u200eأسود منتصف الليل\u200e',
#   'model': '\u200eنوفا 9 SE\u200e',
#   'meta_keyword': 'هواوي,هواوي) نوفا),51096XGH,سعة 128 جيجابايت,أسود منتصف الليل,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1199,
#   'special_price': 949,
#   'after': 825.2174,
#   'name': '(Huawei) nova',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200e4\u200eG LTE\u200e',
#   'Colour': '\u200eكوالكوم سناب دراغون 680 6 nm\u200e',
#   'model': '\u200eنوفا 9 SE\u200e',
#   'meta_keyword': 'هواوي,هواوي) نوفا),51096XGK,سعة 128 جيجابايت,أبيض لؤلؤي,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1199,
#   'special_price': 949,
#   'after': 825.2174,
#   'name': 'موتورولا) موتو جي)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e6 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 695\u200e',
#   'Colour': '\u200eرمادي نيزكي\u200e',
#   'model': '\u200eموتو جي 82\u200e',
#   'meta_keyword': 'موتورولا,موتورولا) موتو جي),PAUA0019AE,سعة 128 جيجابايت,رمادي نيزكي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1199,
#   'special_price': 949,
#   'after': 825.2174,
#   'name': 'موتورولا) موتو جي)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e6 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 695\u200e',
#   'Colour': '\u200eWhite Lily\u200e',
#   'model': '\u200eموتو جي 82\u200e',
#   'meta_keyword': 'موتورولا,موتورولا) موتو جي),PAUA0049AE,سعة 128 جيجابايت,,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1249,
#   'special_price': 1099,
#   'after': 955.6522,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e6 جيجابايت رام\u200e',
#   'processer': '\u200e اكسينوس\u200e',
#   'Colour': '\u200eبرتقالي\u200e',
#   'model': '\u200eجالكسي ايه33\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA336EZOGMEA,سعة 128 جيجابايت,برتقالي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1249,
#   'special_price': 1099,
#   'after': 955.6522,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e6 جيجابايت رام\u200e',
#   'processer': '\u200e اكسينوس\u200e',
#   'Colour': '\u200e ابيض\u200e',
#   'model': '\u200eجالكسي ايه33\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA336EZWGMEA,سعة 128 جيجابايت, ابيض,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1249,
#   'special_price': 1099,
#   'after': 955.6522,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e6 جيجابايت رام\u200e',
#   'processer': '\u200e اكسينوس\u200e',
#   'Colour': '\u200eاسود\u200e',
#   'model': '\u200eجالكسي ايه33\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA336EZKGMEA,سعة 128 جيجابايت,اسود,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1249,
#   'special_price': 1099,
#   'after': 955.6522,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e6 جيجابايت رام\u200e',
#   'processer': '\u200e اكسينوس\u200e',
#   'Colour': '\u200eأزرق فاتح\u200e',
#   'model': '\u200eجالكسي ايه33\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA336ELBGMEA,سعة 128 جيجابايت,ازرق فاتح,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2999,
#   'special_price': 2799,
#   'after': 2433.913,
#   'name': 'آبل) ايفون 12)',
#   'capcity_GB': '\u200e64\u200e GB\u200e',
#   'RAM': '\u200eازرق\u200e',
#   'processer': "\u200e'                                                            أبل ايه14 بايونيك\u200e",
#   'Colour': None,
#   'model': '\u200eايفون 12\u200e',
#   'meta_keyword': 'ابل,آبل) ايفون 12),MGJ83AAA,64 GB,ازرق,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3499,
#   'special_price': 3299,
#   'after': 2868.6957,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eازرق\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLNG3AHA,سعة 128 جيجابايت,ازرق,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3499,
#   'special_price': 3299,
#   'after': 2868.6957,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eلون ضوء النجوم\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLND3AHA,سعة 128 جيجابايت,لون ضوء النجوم,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3499,
#   'special_price': 3299,
#   'after': 2868.6957,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eأحمر\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLNF3AHA,سعة 128 جيجابايت,أحمر,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3999,
#   'special_price': 3799,
#   'after': 3303.4783,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200eوردي\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLNK3AHA,سعة 256 جيجابايت,وردي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3499,
#   'special_price': 3299,
#   'after': 2868.6957,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eلون سماء الليل\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLNC3AHA,سعة 128 جيجابايت,لون سماء الليل,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3499,
#   'special_price': 3299,
#   'after': 2868.6957,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eوردي\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLNE3AHA,سعة 128 جيجابايت,وردي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2999,
#   'special_price': 2799,
#   'after': 2433.913,
#   'name': 'آبل) ايفون 12)',
#   'capcity_GB': '\u200e64\u200e GB\u200e',
#   'RAM': '\u200eاسود\u200e',
#   'processer': "\u200e'                                                            أبل ايه14 بايونيك\u200e",
#   'Colour': None,
#   'model': '\u200eايفون 12\u200e',
#   'meta_keyword': 'ابل,آبل) ايفون 12),MGJ53AAA,64 GB,اسود,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2999,
#   'special_price': 2799,
#   'after': 2433.913,
#   'name': 'آبل) ايفون 12)',
#   'capcity_GB': '\u200e64\u200e GB\u200e',
#   'RAM': '\u200eاخضر\u200e',
#   'processer': "\u200e'                                                            أبل ايه14 بايونيك\u200e",
#   'Colour': None,
#   'model': '\u200eايفون 12\u200e',
#   'meta_keyword': 'ابل,آبل) ايفون 12),MGJ93AAA,64 GB,اخضر,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 6799,
#   'special_price': 6599,
#   'after': 5738.2609,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eفضي\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13 برو\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLV33AHA,سعة 1 تيرا بايت,فضي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3999,
#   'special_price': 3799,
#   'after': 3303.4783,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200eأحمر\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLNL3AHA,سعة 256 جيجابايت,أحمر,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3999,
#   'special_price': 3799,
#   'after': 3303.4783,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200eاخضر\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MNGH3AHA,سعة 256 جيجابايت,اخضر,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 6799,
#   'special_price': 6599,
#   'after': 5738.2609,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eلون أزرق سيريا\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13 برو\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLV73AHA,سعة 1 تيرا بايت,لون أزرق سيريا,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2599,
#   'special_price': 2399,
#   'after': 2086.087,
#   'name': 'شاومي سلسلة بوكو فون',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e12 جيجابايت رام\u200e',
#   'processer': '\u200eالجيل الاول \u200e-\u200e كوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eStealth Black\u200e',
#   'model': '\u200eبوكو اف 4 جي تي\u200e',
#   'meta_keyword': 'Xiaomi,شاومي سلسلة بوكو فون,MZB0BJREN,سعة 256 جيجابايت,أسود,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2599,
#   'special_price': 2399,
#   'after': 2086.087,
#   'name': 'شاومي سلسلة بوكو فون',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e12 جيجابايت رام\u200e',
#   'processer': '\u200eالجيل الاول \u200e-\u200e كوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eKnight Silver\u200e',
#   'model': '\u200eبوكو اف 4 جي تي\u200e',
#   'meta_keyword': 'Xiaomi,شاومي سلسلة بوكو فون,MZB0BJIEN,سعة 256 جيجابايت,,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 6799,
#   'special_price': 6599,
#   'after': 5738.2609,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eجرافيتي\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13 برو\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLV13AHA,سعة 1 تيرا بايت,جرافيتي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3999,
#   'special_price': 3799,
#   'after': 3303.4783,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200eلون ضوء النجوم\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLNJ3AHA,سعة 256 جيجابايت,لون ضوء النجوم,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3499,
#   'special_price': 3299,
#   'after': 2868.6957,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eاخضر\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MNGG3AHA,سعة 128 جيجابايت,اخضر,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1999,
#   'special_price': 1799,
#   'after': 1564.3478,
#   'name': 'أوبو رينو',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eميدياتك ديمنستي 900\u200e',
#   'Colour': '\u200eأسود\u200e',
#   'model': '\u200eرينو 7\u200e',
#   'meta_keyword': 'أوبو,أوبو رينو,CPH2371BLK,سعة 256 جيجابايت,أسود,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1999,
#   'special_price': 1799,
#   'after': 1564.3478,
#   'name': 'أوبو رينو',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eميدياتك ديمنستي 900\u200e',
#   'Colour': '\u200eأزرق استارترايلس\u200e',
#   'model': '\u200eرينو 7\u200e',
#   'meta_keyword': 'أوبو,أوبو رينو,CPH2371BLU,سعة 256 جيجابايت,أزرق استارترايلس,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1699,
#   'special_price': 1499,
#   'after': 1303.4783,
#   'name': 'موتورولا) ايدج)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eبلوري أبيض\u200e',
#   'Colour': None,
#   'model': '\u200eادج 20\u200e',
#   'meta_keyword': 'موتورولا,موتورولا) ايدج),PAR00052AE,سعة 128 جيجابايت,بلوري أبيض,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 6799,
#   'special_price': 6599,
#   'after': 5738.2609,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eأخضر صنوبري\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13 برو\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MNE13AHA,سعة 1 تيرا بايت,أخضر صنوبري,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3999,
#   'special_price': 3799,
#   'after': 3303.4783,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200eازرق\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLNM3AHA,سعة 256 جيجابايت,ازرق,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2599,
#   'special_price': 2399,
#   'after': 2086.087,
#   'name': 'شاومي سلسلة بوكو فون',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e12 جيجابايت رام\u200e',
#   'processer': '\u200eالجيل الاول \u200e-\u200e كوالكوم سناب دراغون 8\u200e',
#   'Colour': '\u200eCyber Yellow\u200e',
#   'model': '\u200eبوكو اف 4 جي تي\u200e',
#   'meta_keyword': 'Xiaomi,شاومي سلسلة بوكو فون,MZB0BJHEN,سعة 256 جيجابايت,,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1199,
#   'special_price': 999,
#   'after': 868.6957,
#   'name': 'لا ينطبق',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e6 جيجابايت رام\u200e',
#   'processer': '\u200eميدياتك ديمنستي 720 \u200e5\u200eG\u200e',
#   'Colour': '\u200eلون معدن الاسلحة الكهربائية\u200e',
#   'model': '\u200eادج 20 لايت 5 جي\u200e',
#   'meta_keyword': 'موتورولا,لا ينطبق,PANE0071SA,سعة 128 جيجابايت,لون معدن الاسلحة الكهربائية,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 3999,
#   'special_price': 3799,
#   'after': 3303.4783,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200eلون سماء الليل\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLNH3AHA,سعة 256 جيجابايت,لون سماء الليل,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 899,
#   'special_price': 699,
#   'after': 607.8261,
#   'name': 'موتورولا) موتو جي)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e6 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 680\u200e',
#   'Colour': '\u200eلون روز معدني\u200e',
#   'model': '\u200eموتو جي 42\u200e',
#   'meta_keyword': 'موتورولا,موتورولا) موتو جي),PAU00013AE,سعة 128 جيجابايت,لون روز معدني,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 899,
#   'special_price': 699,
#   'after': 607.8261,
#   'name': 'موتورولا) موتو جي)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e6 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 680\u200e',
#   'Colour': '\u200eلون الاخضر الاطلسي\u200e',
#   'model': '\u200eموتو جي 42\u200e',
#   'meta_keyword': 'موتورولا,موتورولا) موتو جي),PAU00018AE,سعة 128 جيجابايت,,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 6799,
#   'special_price': 6599,
#   'after': 5738.2609,
#   'name': 'آبل) آيفون 13)',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eذهبي\u200e',
#   'processer': '\u200eآبل أيه 15 بايونيك\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 13 برو\u200e',
#   'meta_keyword': 'ابل,آبل) آيفون 13),MLV43AHA,سعة 1 تيرا بايت,ذهبي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1899,
#   'special_price': 1799,
#   'after': 1564.3478,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 778 جي\u200e',
#   'Colour': '\u200eرمادي\u200e',
#   'model': '\u200eجالكسي ايه73\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA736BZAGMEA,سعة 128 جيجابايت,رمادي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1899,
#   'special_price': 1799,
#   'after': 1564.3478,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 778 جي\u200e',
#   'Colour': '\u200e ابيض\u200e',
#   'model': '\u200eجالكسي ايه73\u200e',
# ...
#   'model': '\u200e ايفون 14 برو ماكس\u200e',
#   'meta_keyword': 'ابل,MQ9L3AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 6199,
#   'special_price': None,
#   'after': 5390.4348,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200e512\u200e GB\u200e',
#   'RAM': '\u200eبنفسجي غامق\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 14 برو\u200e',
#   'meta_keyword': 'ابل,MQ283AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2799,
#   'special_price': None,
#   'after': 2433.913,
#   'name': 'أوبو رينو',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e12 جيجابايت رام\u200e',
#   'processer': '\u200eميدياتك ديمنستي 1200 ماكس\u200e',
#   'Colour': '\u200eأزرق استارترايلس\u200e',
#   'model': '\u200eرينو 7 برو\u200e',
#   'meta_keyword': 'أوبو,أوبو رينو,CPH2293BLU,سعة 256 جيجابايت,أزرق استارترايلس,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2199,
#   'special_price': None,
#   'after': 1912.1739,
#   'name': 'فيفو في',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e12 جيجابايت رام\u200e',
#   'processer': '\u200eذهبي الشروق\u200e',
#   'Colour': None,
#   'model': 'V23',
#   'meta_keyword': 'vivo,فيفو في,5660408,سعة 256 جيجابايت,ذهبي الشروق,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 2049,
#   'special_price': None,
#   'after': 1781.7391,
#   'name': 'آبل آيفون اس اي',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e4\u200eG LTE\u200e',
#   'processer': '\u200e ابيض\u200e',
#   'Colour': None,
#   'model': '\u200eآيفون اس اي الاصدار 2\u200e',
#   'meta_keyword': 'ابل,آبل آيفون اس اي,MHGU3AAA,سعة 128 جيجابايت, ابيض,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 5199,
#   'special_price': None,
#   'after': 4520.8696,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eأسود فلكي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200e ايفون 14 برو ماكس\u200e',
#   'meta_keyword': 'ابل,MQ963AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 5199,
#   'special_price': None,
#   'after': 4520.8696,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eبنفسجي غامق\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200e ايفون 14 برو ماكس\u200e',
#   'meta_keyword': 'ابل,MQ993AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 5199,
#   'special_price': None,
#   'after': 4520.8696,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eفضي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200e ايفون 14 برو ماكس\u200e',
#   'meta_keyword': 'ابل,MQ973AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 7699,
#   'special_price': None,
#   'after': 6694.7826,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eأسود فلكي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200e ايفون 14 برو ماكس\u200e',
#   'meta_keyword': 'ابل,MQ9K3AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 4699,
#   'special_price': None,
#   'after': 4086.087,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eفضي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 14 برو\u200e',
#   'meta_keyword': 'ابل,MQ013AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1999,
#   'special_price': None,
#   'after': 1477.3913,
#   'name': 'شاومي سلسلة 11',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eميدياتك ديمنستي 1200 اولتره\u200e',
#   'Colour': '\u200eأبيض مون لايت\u200e',
#   'model': '\u200e11 تي\u200e',
#   'meta_keyword': 'Xiaomi,شاومي سلسلة 11,MZB09MOEN,سعة 256 جيجابايت,أبيض مون لايت,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1899,
#   'special_price': None,
#   'after': 1520.8696,
#   'name': 'شاومي سلسلة ريدمي',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eميدياتك ديمنستي 920\u200e',
#   'Colour': '\u200eنجمة زرقاء\u200e',
#   'model': '\u200e+ريدمي نوت 11 برو \u200e5\u200eG\u200e',
#   'meta_keyword': 'Xiaomi,شاومي سلسلة ريدمي,MZB0AGIEN,سعة 256 جيجابايت,نجمة زرقاء,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 7699,
#   'special_price': None,
#   'after': 6694.7826,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eذهبي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200e ايفون 14 برو ماكس\u200e',
#   'meta_keyword': 'ابل,MQ9M3AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1499,
#   'special_price': None,
#   'after': 999.1304,
#   'name': 'شاومي سلسلة 11',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eكوالكوم سناب دراغون 778 جي\u200e',
#   'Colour': '\u200eأزرق زاهي\u200e',
#   'model': '\u200e11 لايت NE \u200e5\u200eG\u200e',
#   'meta_keyword': 'Xiaomi,شاومي سلسلة 11,MZB09TOEN,سعة 128 جيجابايت,أزرق زاهي,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 7199,
#   'special_price': None,
#   'after': 6260,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eبنفسجي غامق\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 14 برو\u200e',
#   'meta_keyword': 'ابل,MQ313AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 6199,
#   'special_price': None,
#   'after': 5390.4348,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200e512\u200e GB\u200e',
#   'RAM': '\u200eفضي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 14 برو\u200e',
#   'meta_keyword': 'ابل,MQ1V3AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 5699,
#   'special_price': None,
#   'after': 4955.6522,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200eذهبي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200e ايفون 14 برو ماكس\u200e',
#   'meta_keyword': 'ابل,MQ9D3AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 1299,
#   'special_price': None,
#   'after': 955.6522,
#   'name': 'فيفو واي',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eدريم غلوو\u200e',
#   'Colour': None,
#   'model': 'Y72',
#   'meta_keyword': 'vivo,فيفو واي,5657257,سعة 128 جيجابايت,دريم غلوو,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 5199,
#   'special_price': None,
#   'after': 4520.8696,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200eذهبي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 14 برو\u200e',
#   'meta_keyword': 'ابل,MQ173AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 999,
#   'special_price': None,
#   'after': 0,
#   'name': 'هونر سلسلة 50',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200e فضي سبيس\u200e',
#   'Colour': None,
#   'model': '\u200e50 لايت\u200e',
#   'meta_keyword': 'هونر,هونر سلسلة 50,5109ABFJ,سعة 128 جيجابايت, فضي سبيس,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 849,
#   'special_price': None,
#   'after': 694.7826,
#   'name': 'شاومي سلسلة ريدمي',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e4 جيجابايت رام\u200e',
#   'processer': '\u200e7) ميدياتك ديمنستي 700\u200enm)\u200e',
#   'Colour': '\u200eChrome Silver\u200e',
#   'model': '\u200eريدمي نوت 10 \u200e5\u200eG\u200e',
#   'meta_keyword': 'Xiaomi,شاومي سلسلة ريدمي,MZB0907EN,سعة 128 جيجابايت,,5G,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 6699,
#   'special_price': None,
#   'after': 5825.2174,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200e512\u200e GB\u200e',
#   'RAM': '\u200eذهبي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200e ايفون 14 برو ماكس\u200e',
#   'meta_keyword': 'ابل,MQ9H3AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 7199,
#   'special_price': None,
#   'after': 6260,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 1 تيرا بايت\u200e',
#   'RAM': '\u200eذهبي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 14 برو\u200e',
#   'meta_keyword': 'ابل,MQ2U3AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 999,
#   'special_price': None,
#   'after': 868.6957,
#   'name': 'هونر سلسلة 50',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e8 جيجابايت رام\u200e',
#   'processer': '\u200eأسود\u200e',
#   'Colour': None,
#   'model': '\u200e50 لايت\u200e',
#   'meta_keyword': 'هونر,هونر سلسلة 50,5109ABFE,سعة 128 جيجابايت,أسود,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 4699,
#   'special_price': None,
#   'after': 4086.087,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eأسود فلكي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 14 برو\u200e',
#   'meta_keyword': 'ابل,MPXU3AH/A,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 729,
#   'special_price': None,
#   'after': 633.913,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e4 جيجابايت رام\u200e',
#   'processer': '\u200e اكسينوس\u200e',
#   'Colour': '\u200eاسود\u200e',
#   'model': '\u200eجالكسي ايه13\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA135FZKHMEA,سعة 128 جيجابايت,اسود,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 4699,
#   'special_price': None,
#   'after': 4086.087,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200eبنفسجي غامق\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 14 برو\u200e',
#   'meta_keyword': 'ابل,MQ0F3AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 949,
#   'special_price': None,
#   'after': 651.3043,
#   'name': 'شاومي سلسلة ريدمي',
#   'capcity_GB': '\u200eسعة 128 جيجابايت\u200e',
#   'RAM': '\u200e6 جيجابايت رام\u200e',
#   'processer': '\u200eاونيكس الرمادي\u200e',
#   'Colour': None,
#   'model': '\u200eريدمي نوت 10 اس\u200e',
#   'meta_keyword': 'Xiaomi,شاومي سلسلة ريدمي,MZB092REN,سعة 128 جيجابايت,اونيكس الرمادي,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 6199,
#   'special_price': None,
#   'after': 5390.4348,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200e512\u200e GB\u200e',
#   'RAM': '\u200eأسود فلكي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 14 برو\u200e',
#   'meta_keyword': 'ابل,MQ1L3AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 5199,
#   'special_price': None,
#   'after': 4520.8696,
#   'name': '\u200eآبل) آيفون 14)\u200e',
#   'capcity_GB': '\u200eسعة 256 جيجابايت\u200e',
#   'RAM': '\u200eأسود فلكي\u200e',
#   'processer': '\u200eApple A16\u200e Bionic\u200e',
#   'Colour': None,
#   'model': '\u200eايفون 14 برو\u200e',
#   'meta_keyword': 'ابل,MQ0Q3AHA,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 369,
#   'special_price': None,
#   'after': 320.8696,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200e32\u200e GB\u200e',
#   'RAM': '\u200e2 جيجابايت رام\u200e',
#   'processer': '\u200eيونسوك SC9863\u200eA\u200e',
#   'Colour': '\u200eازرق\u200e',
#   'model': '\u200eجالكسي ايه03 كور\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA032FZBDMEA,32 GB,ازرق,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 529,
#   'special_price': None,
#   'after': 425.2174,
#   'name': 'نوكيا جي',
#   'capcity_GB': '\u200e64\u200e GB\u200e',
#   'RAM': '\u200e4 جيجابايت رام\u200e',
#   'processer': '\u200eالغسق\u200e',
#   'Colour': None,
#   'model': 'G10',
#   'meta_keyword': 'نوكيا,نوكيا جي,719901147881,64 GB,الغسق,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 529,
#   'special_price': None,
#   'after': 425.2174,
#   'name': 'نوكيا جي',
#   'capcity_GB': '\u200e64\u200e GB\u200e',
#   'RAM': '\u200e4 جيجابايت رام\u200e',
#   'processer': '\u200eليل\u200e',
#   'Colour': None,
#   'model': 'G10',
#   'meta_keyword': 'نوكيا,نوكيا جي,719901147871,64 GB,ليل,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 369,
#   'special_price': None,
#   'after': 320.8696,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200e32\u200e GB\u200e',
#   'RAM': '\u200e2 جيجابايت رام\u200e',
#   'processer': '\u200eيونسوك SC9863\u200eA\u200e',
#   'Colour': '\u200eاسود\u200e',
#   'model': '\u200eجالكسي ايه03 كور\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA032FZKDMEA,32 GB,اسود,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'},
#  {'before': 369,
#   'special_price': None,
#   'after': 303.4783,
#   'name': 'سامسونج) جالكسي ايه)',
#   'capcity_GB': '\u200e32\u200e GB\u200e',
#   'RAM': '\u200e2 جيجابايت رام\u200e',
#   'processer': '\u200eيونسوك SC9863\u200eA\u200e',
#   'Colour': '\u200eاونيكس الاسود\u200e',
#   'model': '\u200eجالكسي ايه03 كور\u200e',
#   'meta_keyword': 'سامسونج,سامسونج) جالكسي ايه),SMA032FCKDMEA,32 GB,اونيكس الاسود,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي'}]

# %%
import pandas as pd
pd.DataFrame(list_prices).to_csv("PATH.csv")

# %%
pd.read_csv('PATH.csv')
# Out:
#      Unnamed: 0  before  special_price      after                  name  \
# 0             0    2499            NaN  2173.0435       موتورولا) ايدج)
# 1             1    6799         5699.0  4955.6522   سامسونج) جالكسي زد)
# 2             2    6799         5699.0  4955.6522   سامسونج) جالكسي زد)
# 3             3    6799         5699.0  4955.6522   سامسونج) جالكسي زد)
# 4             4    3999         2899.0  2520.8696   سامسونج) جالكسي زد)
# ..          ...     ...            ...        ...                   ...
# 474         474     499            NaN   433.9130  سامسونج) جالكسي ايه)
# 475         475     529            NaN   425.2174              نوكيا جي
# 476         476     529            NaN   425.2174              نوكيا جي
# 477         477     509            NaN   425.2174     شاومي سلسلة ريدمي
# 478         478     369            NaN   303.4783  سامسونج) جالكسي ايه)
#
#              capcity_GB                RAM                       processer  \
# 0    ‎سعة 256 جيجابايت‎  ‎12 جيجابايت رام‎       ‎كوالكوم سناب دراغون 888‎
# 1    ‎سعة 256 جيجابايت‎  ‎12 جيجابايت رام‎  ‎كوالكوم سناب دراغون 888 5 جي‎
# 2    ‎سعة 256 جيجابايت‎  ‎12 جيجابايت رام‎  ‎كوالكوم سناب دراغون 888 5 جي‎
# 3    ‎سعة 256 جيجابايت‎  ‎12 جيجابايت رام‎                           ‎فضي‎
# 4    ‎سعة 256 جيجابايت‎   ‎8 جيجابايت رام‎                    ‎لون لخزامى‎
# ..                  ...                ...                             ...
# 474            ‎64‎ GB‎   ‎4 جيجابايت رام‎                          ‎ازرق‎
# 475            ‎64‎ GB‎   ‎4 جيجابايت رام‎                         ‎الغسق‎
# 476            ‎64‎ GB‎   ‎4 جيجابايت رام‎                           ‎ليل‎
# 477            ‎64‎ GB‎   ‎3 جيجابايت رام‎           ‎ميدياتك هيليو جي 25‎
# 478            ‎32‎ GB‎   ‎2 جيجابايت رام‎               ‎يونسوك SC9863‎A‎
#
#                  Colour               model  \
# 0    ‎لون رمادي كوزميك‎      Edge 30 Fusion
# 1                ‎اسود‎  ‎جالكسي زد فولد 3‎
# 2                ‎اخضر‎  ‎جالكسي زد فولد 3‎
# 3                   NaN  ‎جالكسي زد فولد 3‎
# 4                   NaN  ‎جالكسي زد فليب 3‎
# ..                  ...                 ...
# 474                 NaN      ‎جالكسي ايه03‎
# 475                 NaN                 G10
# 476                 NaN                 G10
# 477        ‎أزرق سماوي‎       ‎ريدمي ‎10‎A‎
# 478             ‎نحاسي‎  ‎جالكسي ايه03 كور‎
#
#                                           meta_keyword
# 0    موتورولا,موتورولا) ايدج),PAUN0043SA,سعة 256 جي...
# 1    سامسونج,سامسونج) جالكسي زد),SMF926BZKDMEA,سعة ...
# 2    سامسونج,سامسونج) جالكسي زد),SMF926BZGDMEA,سعة ...
# 3    سامسونج,سامسونج) جالكسي زد),SMF926BZSDMEA,سعة ...
# 4    سامسونج,سامسونج) جالكسي زد),SMF711BLVFMEA,سعة ...
# ..                                                 ...
# 474  سامسونج,سامسونج) جالكسي ايه),SMA035FZBGMEA,64 ...
# 475  نوكيا,نوكيا جي,719901147881,64 GB,الغسق,4G LTE...
# 476  نوكيا,نوكيا جي,719901147871,64 GB,ليل,4G LTE,ا...
# 477  Xiaomi,شاومي سلسلة ريدمي,MZB0B7WEN,64 GB,أزرق ...
# 478  سامسونج,سامسونج) جالكسي ايه),SMA032FZCDMEA,32 ...
#
# [479 rows x 11 columns]

# %%
list_error_items
# Out:
# [{'link': '/api/catalogv1/product/store/sa-ar/category_ids/1008/aggregation/true/size/12/from/{}/sort-priority/asc',
#   'object': {'_index': 'vue_storefront_catalog_sa_ar_2022-10-04',
#    '_type': 'product',
#    '_id': '432037',
#    '_score': None,
#    '_source': {'attribute_set_id': 423,
#     'created_at': '2021-11-28 09:35:09',
#     'updated_at': '2022-10-04 06:42:07',
#     'type_id': 'simple',
#     'sku': '543128',
#     'id': 432037,
#     'media_gallery': [{'type': 'image',
#       'image': 'm1images/5/4/543128.jpg',
#       'lab': '',
#       'pos': 0}],
#     'tsk': 1664864066,
#     'name': '\u200e4\u200eG LTE ,أبيض أورا ,\u200e512\u200e GB ,\u200e جالكسي نوت 10 بلس\u200e \u200eسامسونج\u200e منتج مجدد درجة ب\u200e',
#     'meta_title': 'سامسونج سامسونج) جالكسي نوت) أبيض أورا منتج مجدد درجة ب في مكتبة جرير السعودية اونلاين',
#     'meta_description': 'اشتر منتج مجدد درجة ب سامسونج سامسونج) جالكسي نوت) أبيض أورا 4G LTE smartphone في مكتبة جرير لأفضل العروض و الأسعار في الدمام، الرياض، جدة، السعودية. قارن الخصائص، المواصفات للتسوق اونلاين على موقع مكتبة جرير jarir.com',
#     'url_key': 'samsung-galaxy-note10-plus-renewed-smartphones-543128',
#     'is_returnable': True,
#     'fulfilment_type': 'LIVE',
#     'fulfilment_method': 'NORMAL',
#     'is_cashback': True,
#     'arabicname_field1': '\u200eمنتج مجدد درجة ب\u200e',
#     'arabicname_field2': '\u200e\u200eسامسونج\u200e\u200e',
#     'arabicname_field3': '\u200e\u200e جالكسي نوت 10 بلس\u200e\u200e',
#     'arabicname_field4': '\u200e512\u200e GB\u200e',
#     'arabicname_field5': '\u200eأبيض أورا\u200e',
#     'arabicname_field6': '\u200e4\u200eG LTE\u200e',
#     'bar_code1': None,
#     'bar_code2': None,
#     'box_height': '7.00',
#     'box_length': '18.50',
#     'box_width': '10.00',
#     'brand': 'سامسونج',
#     'cazo': None,
#     'dept': '\u200eلا ينطبق\u200e',
#     'dim_uom': 'CM',
#     'feat': '\u200eWater\u200e-\u200eresistant, Face Recognition, Wireless PowerShare\u200e',
#     'gl_class': 'IN05',
#     'heig': '\u200eلا ينطبق\u200e',
#     'item_classification': 'ECA',
#     'item_number': '16-SMN975FZWGKRB',
#     'item_prefix': '16-',
#     'model': '\u200e جالكسي نوت 10 بلس\u200e',
#     'mpn': 'SMN975FZWGKSA',
#     'port': '\u200eيو أس  بي تايب سي\u200e',
#     'productcode_description': 'هواتف ذكية مجددة',
#     'rnrm': '\u200e532563\u200e\u200e',
#     'addtocart': '1',
#     'discountable': '0',
#     'jarir_master_tag': '28',
#     'jarir_tag_one': '38',
#     'jarir_tag_two': None,
#     'jb_tax_class_code': 'KSAVAT5',
#     'priority_qty': None,
#     'priority_val': None,
#     'sens': '\u200eAccelerometer, Barometer, Geomagnetic, Gyro, Hall, Light, Proximity\u200e',
#     'serial_required': 'N',
#     'uom': 'Each',
#     'uom_code': 'EA',
#     'uom_desc': 'Each',
#     'video_url': None,
#     'weig': '\u200eلا ينطبق\u200e',
#     'weight_uom': 'KG',
#     'widt': '\u200eلا ينطبق\u200e',
#     'naming_formula': 'arabicname_field1*arabicname_field2*arabicname_field3*arabicname_field4*arabicname_field5*arabicname_field6',
#     'item_warranty_code': '16-ASP06Y2',
#     'family_code': 'RPALOS',
#     'before_addtocart_popup_block': None,
#     'below_pdp_image_block': None,
#     'how_to_content_block': None,
#     'how_to_content_popup_block': None,
#     'popup_block': None,
#     'incomplete_status_changed_kuwait': None,
#     'incomplete_status_changed_saudi': None,
#     'tamara_category': 'Category 3',
#     'renewed_oos_status_changed_saudi': None,
#     'description': 'default',
#     'short_description': 'GALAXY NOTE 10 PLUS 512GB WHT',
#     'meta_keyword': 'منتج مجدد درجة ب,سامسونج,سامسونج) جالكسي نوت),أبيض أورا,4G LTE,SMN975FZWGKSA,مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات',
#     'additional_information': None,
#     'suggested_accessories': [{'title': {'en_US': 'Smartwatch',
#        'ar_SA': 'ساعةذكية'},
#       'skus': '532373',
#       'updated_on': '2021-12-02 09:08:11',
#       'action_hash': '10505c66c5ff44ff951b99f4911c976b'},
#      {'title': {'en_US': 'Other Smartphone Accessories',
#        'ar_SA': 'لوازم الهواتف الذكية'},
#       'skus': '531430,559600,559606',
#       'updated_on': '2021-12-08 01:35:06',
#       'action_hash': '580fab1ea45731b7586d8221f68c601d'}],
#     'producttag_data': None,
#     'alternative_item': '579022',
#     'klevu_search_keywords': 'Renewed Grade B, Samsung Galaxy Note10+, 512 GB, Aura White, 4G LTE, Smartphone',
#     'bought_together': '568437,568435,552857,560477,565161,581939,568477,581801,565160,567804',
#     'price': 4927.48,
#     'special_price': 2479,
#     'weight': 0.53,
#     'max_sale_qty': 5,
#     'min_sale_qty': 1,
#     'qty_increments': 1,
#     'price_ex_tax': 4284.7652,
#     'final_price_ex_tax': 2155.6522,
#     'jb_discount_percentage': 49,
#     'promotion_value': 2448.48,
#     'product_save': 2448.48,
#     'special_price_ex_vat': 2155.66,
#     'base_price_ex_vat': None,
#     'jarir_final_price': 2479,
#     'special_from_date': '2022-10-04 00:00:00',
#     'special_to_date': '2022-10-05 00:00:00',
#     'jb_product_update_at': '2022-10-03 20:12:22',
#     'status': 1,
#     'visibility': 4,
#     'tax_class_id': 0,
#     'priority': 552060,
#     'customer_limit': 0,
#     'cashoncollection_enable': 1,
#     'cod_enable': 1,
#     'pay_at_store': 1,
#     'showroom_collection': 1,
#     'homedelivery_enable': 1,
#     'international_shipping': '0',
#     'acce': 'Power Bank Charger/USB Car Charger/Gimbal Stabilizer/Stabilized Smart Camera',
#     'apst': None,
#     'baca': '4200 mAh',
#     'baty': 'لا ينطبق',
#     'cars': 'الخلفية: 12 + 12 ميجابيكسل، الامامية: 5 ميجابيكسل',
#     'chip': 'لا ينطبق',
#     'cofa': '49823',
#     'colo': '65743',
#     'cote': 'بلوتوث - واي فاي',
#     'cpuf': 'لا ينطبق',
#     'dipr': 'لا ينطبق',
#     'exsl': 'لا ينطبق',
#     'fing': 'نعم',
#     'flty': 'لا ينطبق',
#     'gpss': 'نعم',
#     'gpuf': 'لا ينطبق',
#     'moos': None,
#     'mxrs': 'لا ينطبق',
#     'nesu': '4G LTE',
#     'nfcf': None,
#     'nsim': 'شريحتين 4 جي، 2 جي',
#     'opsy': 'أندرويد 9.0 باي',
#     'prsd': 'لا ينطبق',
#     'ptyp': 'هاتف ذكي',
#     'quch': 'لا ينطبق',
#     'reba': 'لا ينطبق',
#     'rnwg': '\u200eمنتج مجدد درجة ب\u200e',
#     'scsz': '6.8 بوصة',
#     'scty': 'شاشة سوبر اموليد بتقنية اللمس التكاثفي',
#     'seri': 'سامسونج) جالكسي نوت)',
#     'sity': '(شريحة نانو (صغيرة',
#     'symm': '12 جيجابايت رام',
#     'tsca': None,
#     'vicr': 'لا ينطبق',
#     'check_availability_status': 1,
#     'disabled_item_visibility': None,
#     'manual_sugg_accs': None,
#     'klevu_stock_flag': 0,
#     'tamara_enable': 1,
#     'is_showroom_delivery': True,
#     'jarir_cofa': 'ابيض',
#     'jarir_colo': 'أبيض أورا',
#     'slug': 'samsung-galaxy-note10-plus-renewed-smartphones-543128',
#     'url_path': 'samsung-galaxy-note10-plus-renewed-smartphones-543128.html',
#     'small_image': 'm1images/5/4/543128.jpg',
#     'image': 'm1images/5/4/543128.jpg',
#     'thumbnail': 'm1images/5/4/543128.jpg',
#     'gift_item_count': 0,
#     'jarir_mega_discount': '50%',
#     'product_description_url': 'https://vsf.jarir.com/productdescription?sku=543128',
#     'display_button': 'NO_BUTTON',
#     'category': [{'category_id': 1008,
#       'name': 'الهواتف الذكية',
#       'position': 11,
#       'level': 2},
#      {'category_id': 1017, 'name': 'سامسونج', 'position': 14, 'level': 3},
#      {'category_id': 1029,
#       'name': 'الهواتف الذكية',
#       'position': 19,
#       'level': 3},
#      {'category_id': 5, 'name': 'Default Category', 'position': 1, 'level': 1},
#      {'category_id': 1180,
#       'name': 'العروض الأسبوعية',
#       'position': 22,
#       'level': 2},
#      {'category_id': 1025, 'name': 'أفضل العروض', 'position': 22, 'level': 3},
#      {'category_id': 1733, 'name': 'أفضل العروض', 'position': 66, 'level': 2}],
#     'category_ids': [1008, 1017, 1029, 5, 1180, 1025, 1733],
#     'final_price': 2479,
#     'regular_price': 4927.48,
#     'product_links': [],
#     'configurable_children': [],
#     'parent_sku': [],
#     'brands_data': {'code': 'samsung',
#      'content_provider': 'flixmedia',
#      'image': 'b/4/c/a/b4cad588bc79e450085462601d5b7a08766815ab_samsung.png',
#      'label': 'سامسونج',
#      'id': 2245,
#      'tsk': 1664864066,
#      'label_translation': 'Samsung'}},
#    'sort': [552060]}},
#  {'link': '/api/catalogv1/product/store/sa-ar/category_ids/1008/aggregation/true/size/12/from/{}/sort-priority/asc',
#   'object': {'_index': 'vue_storefront_catalog_sa_ar_2022-10-04',
#    '_type': 'product',
#    '_id': '431990',
#    '_score': None,
#    '_source': {'attribute_set_id': 423,
#     'created_at': '2021-11-28 09:35:09',
#     'updated_at': '2022-10-04 06:42:07',
#     'type_id': 'simple',
#     'sku': '542555',
#     'id': 431990,
#     'media_gallery': [{'type': 'image',
#       'image': 'm1images/5/4/542555.jpg',
#       'lab': '',
#       'pos': 0},
#      {'type': 'image',
#       'image': 'c/0/3/d/c03d5a46fbe23d761606de66bd97ed6c898d714d_542555_1.jpg',
#       'lab': '',
#       'pos': 1}],
#     'tsk': 1664864066,
#     'name': '\u200e4\u200eG LTE ,أبيض أورا ,\u200e512\u200e GB ,\u200e جالكسي نوت 10 بلس\u200e \u200eسامسونج\u200e منتج مجدد درجة أ\u200e',
#     'meta_title': 'سامسونج سامسونج) جالكسي نوت) أبيض أورا منتج مجدد درجة أ في مكتبة جرير السعودية اونلاين',
#     'meta_description': 'اشتر منتج مجدد درجة أ سامسونج سامسونج) جالكسي نوت) أبيض أورا 4G LTE smartphone في مكتبة جرير لأفضل العروض و الأسعار في الدمام، الرياض، جدة، السعودية. قارن الخصائص، المواصفات للتسوق اونلاين على موقع مكتبة جرير jarir.com',
#     'url_key': 'samsung-galaxy-note10-plus-renewed-smartphones-542555',
#     'is_returnable': True,
#     'fulfilment_type': 'LIVE',
#     'fulfilment_method': 'NORMAL',
#     'is_cashback': True,
#     'arabicname_field1': '\u200eمنتج مجدد درجة أ\u200e',
#     'arabicname_field2': '\u200e\u200eسامسونج\u200e\u200e',
#     'arabicname_field3': '\u200e\u200e جالكسي نوت 10 بلس\u200e\u200e',
#     'arabicname_field4': '\u200e512\u200e GB\u200e',
#     'arabicname_field5': '\u200eأبيض أورا\u200e',
#     'arabicname_field6': '\u200e4\u200eG LTE\u200e',
#     'bar_code1': None,
#     'bar_code2': None,
#     'box_height': '7.00',
#     'box_length': '18.50',
#     'box_width': '10.00',
#     'brand': 'سامسونج',
#     'cazo': None,
#     'dept': '\u200eلا ينطبق\u200e',
#     'dim_uom': 'CM',
#     'feat': '\u200eInfinity\u200e-\u200eO Display, Bokeh Video, Eye Comfort Display\u200e',
#     'gl_class': 'IN05',
#     'heig': '\u200eلا ينطبق\u200e',
#     'item_classification': 'ECA',
#     'item_number': '16-SMN975FZWGKRA',
#     'item_prefix': '16-',
#     'model': '\u200e جالكسي نوت 10 بلس\u200e',
#     'mpn': 'SMN975FZWGKRA',
#     'port': '\u200eيو أس  بي تايب سي\u200e',
#     'productcode_description': 'هواتف ذكية مجددة',
#     'rnrm': '\u200e532563\u200e\u200e',
#     'addtocart': '1',
#     'discountable': '0',
#     'jarir_master_tag': '28',
#     'jarir_tag_one': '38',
#     'jarir_tag_two': None,
#     'jb_tax_class_code': 'KSAVAT5',
#     'priority_qty': None,
#     'priority_val': None,
#     'sens': '\u200eAccelerometer, Barometer, Gyro, Geomagnetic, Hall, Light, Proximity\u200e',
#     'serial_required': 'N',
#     'uom': 'Each',
#     'uom_code': 'EA',
#     'uom_desc': 'Each',
#     'video_url': None,
#     'weig': '\u200eلا ينطبق\u200e',
#     'weight_uom': 'KG',
#     'widt': '\u200eلا ينطبق\u200e',
#     'naming_formula': 'arabicname_field1*arabicname_field2*arabicname_field3*arabicname_field4*arabicname_field5*arabicname_field6',
#     'item_warranty_code': '16-ASP06Y2',
#     'family_code': 'RPALOS',
#     'before_addtocart_popup_block': None,
#     'below_pdp_image_block': None,
#     'how_to_content_block': None,
#     'how_to_content_popup_block': None,
#     'popup_block': None,
#     'incomplete_status_changed_kuwait': None,
#     'incomplete_status_changed_saudi': None,
#     'tamara_category': 'Category 3',
#     'renewed_oos_status_changed_saudi': None,
#     'description': 'default',
#     'short_description': 'GALAXY NOTE 10 PLUS 512GB WHT',
#     'meta_keyword': 'منتج مجدد درجة أ,سامسونج,سامسونج) جالكسي نوت),أبيض أورا,4G LTE,SMN975FZWGKRA,مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات',
#     'additional_information': None,
#     'suggested_accessories': [{'title': {'en_US': 'Smartwatch',
#        'ar_SA': 'ساعةذكية'},
#       'skus': '532373',
#       'updated_on': '2021-12-02 09:08:11',
#       'action_hash': '10505c66c5ff44ff951b99f4911c976b'},
#      {'title': {'en_US': 'Other Smartphone Accessories',
#        'ar_SA': 'لوازم الهواتف الذكية'},
#       'skus': '531430,559600,559606',
#       'updated_on': '2021-12-08 01:35:06',
#       'action_hash': '580fab1ea45731b7586d8221f68c601d'}],
#     'producttag_data': None,
#     'alternative_item': '579022',
#     'klevu_search_keywords': 'Renewed Grade A, Samsung Galaxy Note10+, 512 GB, Aura White, 4G LTE, Smartphone',
#     'bought_together': '568437,568435,552857,560477,565161,581939,568477,581801,565160,567804',
#     'price': 4927.48,
#     'special_price': 2639,
#     'weight': 0.53,
#     'max_sale_qty': 5,
#     'min_sale_qty': 1,
#     'qty_increments': 1,
#     'price_ex_tax': 4284.7652,
#     'final_price_ex_tax': 2294.7826,
#     'jb_discount_percentage': 46,
#     'promotion_value': 2288.48,
#     'product_save': 2288.48,
#     'special_price_ex_vat': 2294.79,
#     'base_price_ex_vat': None,
#     'jarir_final_price': 2639,
#     'special_from_date': '2022-10-04 00:00:00',
#     'special_to_date': '2022-10-05 00:00:00',
#     'jb_product_update_at': '2022-10-03 20:12:19',
#     'status': 1,
#     'visibility': 4,
#     'tax_class_id': 0,
#     'priority': 552095,
#     'customer_limit': 0,
#     'cashoncollection_enable': 1,
#     'cod_enable': 1,
#     'pay_at_store': 1,
#     'showroom_collection': 1,
#     'homedelivery_enable': 1,
#     'international_shipping': '0',
#     'acce': 'Power Bank Charger/USB Car Charger/Gimbal Stabilizer/Stabilized Smart Camera',
#     'apst': None,
#     'baca': '4200 mAh',
#     'baty': 'لا ينطبق',
#     'cars': 'الخلفية: 12 + 12 ميجابيكسل، الامامية: 5 ميجابيكسل',
#     'chip': 'لا ينطبق',
#     'cofa': '49823',
#     'colo': '65743',
#     'cote': 'بلوتوث - واي فاي',
#     'cpuf': 'لا ينطبق',
#     'dipr': 'لا ينطبق',
#     'exsl': 'لا ينطبق',
#     'fing': 'نعم',
#     'flty': 'لا ينطبق',
#     'gpss': 'نعم',
#     'gpuf': 'لا ينطبق',
#     'moos': None,
#     'mxrs': 'لا ينطبق',
#     'nesu': '4G LTE',
#     'nfcf': None,
#     'nsim': 'شريحتين 4 جي، 2 جي',
#     'opsy': 'أندرويد 9.0 باي',
#     'prsd': 'لا ينطبق',
#     'ptyp': 'هاتف ذكي',
#     'quch': 'لا ينطبق',
#     'reba': 'لا ينطبق',
#     'rnwg': '\u200eمنتج مجدد درجة أ\u200e',
#     'scsz': '6.8 بوصة',
#     'scty': 'شاشة سوبر اموليد بتقنية اللمس التكاثفي',
#     'seri': 'سامسونج) جالكسي نوت)',
#     'sity': '(شريحة نانو (صغيرة',
#     'symm': '12 جيجابايت رام',
#     'tsca': None,
#     'vicr': 'لا ينطبق',
#     'check_availability_status': 1,
#     'disabled_item_visibility': None,
#     'manual_sugg_accs': None,
#     'klevu_stock_flag': 0,
#     'tamara_enable': 1,
#     'is_showroom_delivery': True,
#     'jarir_cofa': 'ابيض',
#     'jarir_colo': 'أبيض أورا',
#     'slug': 'samsung-galaxy-note10-plus-renewed-smartphones-542555',
#     'url_path': 'samsung-galaxy-note10-plus-renewed-smartphones-542555.html',
#     'small_image': 'm1images/5/4/542555.jpg',
#     'image': 'm1images/5/4/542555.jpg',
#     'thumbnail': 'm1images/5/4/542555.jpg',
#     'gift_item_count': 0,
#     'jarir_mega_discount': '46%',
#     'product_description_url': 'https://vsf.jarir.com/productdescription?sku=542555',
#     'display_button': 'NO_BUTTON',
#     'category': [{'category_id': 1008,
#       'name': 'الهواتف الذكية',
#       'position': 11,
#       'level': 2},
#      {'category_id': 1017, 'name': 'سامسونج', 'position': 14, 'level': 3},
#      {'category_id': 1029,
#       'name': 'الهواتف الذكية',
#       'position': 19,
#       'level': 3},
#      {'category_id': 5, 'name': 'Default Category', 'position': 1, 'level': 1},
#      {'category_id': 1180,
#       'name': 'العروض الأسبوعية',
#       'position': 22,
#       'level': 2},
#      {'category_id': 1025, 'name': 'أفضل العروض', 'position': 22, 'level': 3},
#      {'category_id': 1733, 'name': 'أفضل العروض', 'position': 66, 'level': 2}],
#     'category_ids': [1008, 1017, 1029, 5, 1180, 1025, 1733],
#     'final_price': 2639,
#     'regular_price': 4927.48,
#     'product_links': [],
#     'configurable_children': [],
#     'parent_sku': [],
#     'brands_data': {'code': 'samsung',
#      'content_provider': 'flixmedia',
#      'image': 'b/4/c/a/b4cad588bc79e450085462601d5b7a08766815ab_samsung.png',
#      'label': 'سامسونج',
#      'id': 2245,
#      'tsk': 1664864066,
#      'label_translation': 'Samsung'}},
#    'sort': [552095]}},
#  {'link': '/api/catalogv1/product/store/sa-ar/category_ids/1008/aggregation/true/size/12/from/{}/sort-priority/asc',
#   'object': {'_index': 'vue_storefront_catalog_sa_ar_2022-10-04',
#    '_type': 'product',
#    '_id': '432035',
#    '_score': None,
#    '_source': {'attribute_set_id': 423,
#     'created_at': '2021-11-28 09:35:09',
#     'updated_at': '2022-10-04 06:42:07',
#     'type_id': 'simple',
#     'sku': '543124',
#     'id': 432035,
#     'media_gallery': [{'type': 'image',
#       'image': 'm1images/5/4/543124.jpg',
#       'lab': '',
#       'pos': 0}],
#     'tsk': 1664864066,
#     'name': '\u200e4\u200eG LTE ,Prism Green ,سعة 128 جيجابايت ,\u200eجالكسي اس 10 بلس بشريحتين\u200e \u200eسامسونج\u200e منتج مجدد درجة ب\u200e',
#     'meta_title': 'سامسونج  سامسونج) جالكسي أس) أخضر زجاجي منتج مجدد درجة ب في مكتبة جرير السعودية اونلاين',
#     'meta_description': 'اشتر منتج مجدد درجة ب سامسونج  سامسونج) جالكسي أس) أخضر زجاجي 4G LTE smartphone في مكتبة جرير لأفضل العروض و الأسعار في الدمام، الرياض، جدة، السعودية. قارن الخصائص، المواصفات للتسوق اونلاين على موقع مكتبة جرير jarir.com',
#     'url_key': 'samsung-galaxy-s10-dual-renewed-smartphones-543124',
#     'is_returnable': True,
#     'fulfilment_type': 'LIVE',
#     'fulfilment_method': 'NORMAL',
#     'is_cashback': True,
#     'arabicname_field1': '\u200eمنتج مجدد درجة ب\u200e',
#     'arabicname_field2': '\u200e\u200eسامسونج\u200e\u200e',
#     'arabicname_field3': '\u200e\u200eجالكسي اس 10 بلس بشريحتين\u200e\u200e',
#     'arabicname_field4': '\u200eسعة 128 جيجابايت\u200e',
#     'arabicname_field5': '\u200ePrism Green\u200e',
#     'arabicname_field6': '\u200e4\u200eG LTE\u200e',
#     'bar_code1': None,
#     'bar_code2': None,
#     'box_height': '5.50',
#     'box_length': '17.50',
#     'box_width': '9.00',
#     'brand': 'سامسونج',
#     'cazo': None,
#     'dept': '\u200e7\u200e.80\u200e mm ( .31\u200e in )\u200e',
#     'dim_uom': 'CM',
#     'feat': '\u200eWireless Power Share, Face Recognition\u200e',
#     'gl_class': 'IN05',
#     'heig': '\u200e157\u200e.60\u200e mm ( \u200e6\u200e.20\u200e in )\u200e',
#     'item_classification': 'ECA',
#     'item_number': '16-SMG975FZGDKRB',
#     'item_prefix': '16-',
#     'model': '\u200eجالكسي اس 10 بلس بشريحتين\u200e',
#     'mpn': 'SMG975FZGDKRB',
#     'port': '\u200eUSB\u200e-\u200eC\u200e/\u200e3\u200e.5\u200e mm Audio Jack\u200e',
#     'productcode_description': 'هواتف ذكية مجددة',
#     'rnrm': '\u200e521802\u200e\u200e',
#     'addtocart': '1',
#     'discountable': '0',
#     'jarir_master_tag': '28',
#     'jarir_tag_one': '38',
#     'jarir_tag_two': None,
#     'jb_tax_class_code': 'KSAVAT5',
#     'priority_qty': None,
#     'priority_val': None,
#     'sens': '\u200eAccelerometer, Barometer, Geomagnetic, Gyro, Hall, Light, Proximity\u200e',
#     'serial_required': 'N',
#     'uom': 'Each',
#     'uom_code': 'EA',
#     'uom_desc': 'Each',
#     'video_url': None,
#     'weig': '\u200e175\u200e.00\u200e g ( \u200e6\u200e.18\u200e oz )\u200e',
#     'weight_uom': 'KG',
#     'widt': '\u200e74\u200e.10\u200e mm ( \u200e2\u200e.92\u200e in )\u200e',
#     'naming_formula': 'arabicname_field1*arabicname_field2*arabicname_field3*arabicname_field4*arabicname_field5*arabicname_field6',
#     'item_warranty_code': '16-ASP06Y2',
#     'family_code': 'RPALOS',
#     'before_addtocart_popup_block': None,
#     'below_pdp_image_block': None,
#     'how_to_content_block': None,
#     'how_to_content_popup_block': None,
#     'popup_block': None,
#     'incomplete_status_changed_kuwait': None,
#     'incomplete_status_changed_saudi': None,
#     'tamara_category': 'Category 3',
#     'renewed_oos_status_changed_saudi': None,
#     'description': 'default',
#     'short_description': 'GALAXY S10 PLUS DUAL 128GB GRE EN',
#     'meta_keyword': 'منتج مجدد درجة ب,سامسونج, سامسونج) جالكسي أس),أخضر زجاجي,4G LTE,SMG975FZGDKRB,مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات',
#     'additional_information': None,
#     'suggested_accessories': [{'title': {'en_US': 'Smartwatch',
#        'ar_SA': 'ساعةذكية'},
#       'skus': '532373',
#       'updated_on': '2021-12-02 09:08:11',
#       'action_hash': '10505c66c5ff44ff951b99f4911c976b'},
#      {'title': {'en_US': 'Other Smartphone Accessories',
#        'ar_SA': 'لوازم الهواتف الذكية'},
#       'skus': '531430,559600,559606',
#       'updated_on': '2021-12-08 01:35:06',
#       'action_hash': '580fab1ea45731b7586d8221f68c601d'}],
#     'producttag_data': None,
#     'alternative_item': '579022',
#     'klevu_search_keywords': 'Renewed Grade B, Samsung Galaxy S10+ (DUOS), 128 GB, Prism Green, 4G LTE, Smartphone',
#     'bought_together': '568437,568435,552857,560477,565161,581939,568477,581801,565160,567804',
#     'price': 3941.76,
#     'special_price': 1799,
#     'weight': 0.45,
#     'max_sale_qty': 5,
#     'min_sale_qty': 1,
#     'qty_increments': 1,
#     'price_ex_tax': 3427.6174,
#     'final_price_ex_tax': 1564.3478,
#     'jb_discount_percentage': 54,
#     'promotion_value': 2142.76,
#     'product_save': 2142.76,
#     'special_price_ex_vat': 1564.35,
#     'base_price_ex_vat': None,
#     'jarir_final_price': 1799,
#     'special_from_date': '2022-10-04 00:00:00',
#     'special_to_date': '2022-10-05 00:00:00',
#     'jb_product_update_at': '2022-10-03 20:12:22',
#     'status': 1,
#     'visibility': 4,
#     'tax_class_id': 0,
#     'priority': 552125,
#     'customer_limit': 0,
#     'cashoncollection_enable': 1,
#     'cod_enable': 1,
#     'pay_at_store': 1,
#     'showroom_collection': 1,
#     'homedelivery_enable': 1,
#     'international_shipping': '0',
#     'acce': 'Wireless Charging Pad/Power Bank Charger/Gimbal Stabilizer',
#     'apst': None,
#     'baca': '4100 mAh',
#     'baty': 'بطارية ليثيوم أيون',
#     'cars': 'Rear: 16 MP + 12 MP + 12 MP/Front: 10MP + 8 MP',
#     'chip': 'اكسينوس  9820',
#     'cofa': '49816',
#     'colo': '67944',
#     'cote': 'بلوتوث - واي فاي',
#     'cpuf': 'ام 4 مونجوز + كورتيكس ايه 75 + كورتكس  ايه 55',
#     'dipr': 'كورنينج غوريلا جلاس 6',
#     'exsl': 'ميكرو اس دي، ميكرو اس دي اتش سي، ميكرو اس دي اكس سي - حتى 512 جيجابايت',
#     'fing': 'نعم',
#     'flty': 'نعم',
#     'gpss': 'نعم',
#     'gpuf': 'ARM Mali-G76 MP12',
#     'moos': None,
#     'mxrs': '3040 بيكسل x 1440',
#     'nesu': '4G LTE',
#     'nfcf': None,
#     'nsim': 'شريحة ثنائية (هجين)',
#     'opsy': 'أندرويد 9.0 باي',
#     'prsd': '2.73 + 2.31 + 1.95 GHz',
#     'ptyp': 'هاتف ذكي',
#     'quch': 'شحن سريع للبطارية',
#     'reba': 'لا ينطبق',
#     'rnwg': '\u200eمنتج مجدد درجة ب\u200e',
#     'scsz': '6.4 بوصة',
#     'scty': 'ديناميك اموليد',
#     'seri': ' سامسونج) جالكسي أس)',
#     'sity': '(شريحة نانو (صغيرة',
#     'symm': '8 جيجابايت رام',
#     'tsca': None,
#     'vicr': '2160p@60fps',
#     'check_availability_status': 1,
#     'disabled_item_visibility': None,
#     'manual_sugg_accs': None,
#     'klevu_stock_flag': 0,
#     'tamara_enable': 1,
#     'is_showroom_delivery': True,
#     'jarir_cofa': 'اخضر',
#     'jarir_colo': 'أخضر زجاجي',
#     'slug': 'samsung-galaxy-s10-dual-renewed-smartphones-543124',
#     'url_path': 'samsung-galaxy-s10-dual-renewed-smartphones-543124.html',
#     'small_image': 'm1images/5/4/543124.jpg',
#     'image': 'm1images/5/4/543124.jpg',
#     'thumbnail': 'm1images/5/4/543124.jpg',
#     'gift_item_count': 0,
#     'jarir_mega_discount': '54%',
#     'product_description_url': 'https://vsf.jarir.com/productdescription?sku=543124',
#     'display_button': 'NO_BUTTON',
#     'category': [{'category_id': 1008,
#       'name': 'الهواتف الذكية',
#       'position': 11,
#       'level': 2},
#      {'category_id': 1017, 'name': 'سامسونج', 'position': 14, 'level': 3},
#      {'category_id': 1029,
#       'name': 'الهواتف الذكية',
#       'position': 19,
#       'level': 3},
#      {'category_id': 5, 'name': 'Default Category', 'position': 1, 'level': 1},
#      {'category_id': 1180,
#       'name': 'العروض الأسبوعية',
#       'position': 22,
#       'level': 2},
#      {'category_id': 1025, 'name': 'أفضل العروض', 'position': 22, 'level': 3},
#      {'category_id': 1733, 'name': 'أفضل العروض', 'position': 66, 'level': 2}],
#     'category_ids': [1008, 1017, 1029, 5, 1180, 1025, 1733],
#     'final_price': 1799,
#     'regular_price': 3941.76,
#     'product_links': [],
#     'configurable_children': [],
#     'parent_sku': [],
#     'brands_data': {'code': 'samsung',
#      'content_provider': 'flixmedia',
#      'image': 'b/4/c/a/b4cad588bc79e450085462601d5b7a08766815ab_samsung.png',
#      'label': 'سامسونج',
#      'id': 2245,
#      'tsk': 1664864066,
#      'label_translation': 'Samsung'}},
#    'sort': [552125]}},
#  {'link': '/api/catalogv1/product/store/sa-ar/category_ids/1008/aggregation/true/size/12/from/{}/sort-priority/asc',
#   'object': {'_index': 'vue_storefront_catalog_sa_ar_2022-10-04',
#    '_type': 'product',
#    '_id': '431988',
#    '_score': None,
#    '_source': {'attribute_set_id': 423,
#     'created_at': '2021-11-28 09:35:09',
#     'updated_at': '2022-10-04 06:42:07',
#     'type_id': 'simple',
#     'sku': '542550',
#     'id': 431988,
#     'media_gallery': [{'type': 'image',
#       'image': 'm1images/5/4/542550.jpg',
#       'lab': '',
#       'pos': 0}],
#     'tsk': 1664864066,
#     'name': '\u200e4\u200eG LTE ,Prism Green ,سعة 128 جيجابايت ,\u200eجالكسي اس 10 بلس بشريحتين\u200e \u200eسامسونج\u200e منتج مجدد درجة أ\u200e',
#     'meta_title': 'سامسونج  سامسونج) جالكسي أس) أخضر زجاجي منتج مجدد درجة أ في مكتبة جرير السعودية اونلاين',
#     'meta_description': 'اشتر منتج مجدد درجة أ سامسونج  سامسونج) جالكسي أس) أخضر زجاجي 4G LTE smartphone في مكتبة جرير لأفضل العروض و الأسعار في الدمام، الرياض، جدة، السعودية. قارن الخصائص، المواصفات للتسوق اونلاين على موقع مكتبة جرير jarir.com',
#     'url_key': 'samsung-galaxy-s10-dual-renewed-smartphones-542550',
#     'is_returnable': True,
#     'fulfilment_type': 'LIVE',
#     'fulfilment_method': 'NORMAL',
#     'is_cashback': True,
#     'arabicname_field1': '\u200eمنتج مجدد درجة أ\u200e',
#     'arabicname_field2': '\u200e\u200eسامسونج\u200e\u200e',
#     'arabicname_field3': '\u200e\u200eجالكسي اس 10 بلس بشريحتين\u200e\u200e',
#     'arabicname_field4': '\u200eسعة 128 جيجابايت\u200e',
#     'arabicname_field5': '\u200ePrism Green\u200e',
#     'arabicname_field6': '\u200e4\u200eG LTE\u200e',
#     'bar_code1': None,
#     'bar_code2': None,
#     'box_height': '5.50',
#     'box_length': '17.50',
#     'box_width': '9.00',
#     'brand': 'سامسونج',
#     'cazo': None,
#     'dept': '\u200e7\u200e.80\u200e mm ( .31\u200e in )\u200e',
#     'dim_uom': 'CM',
#     'feat': '\u200eWireless Power Share, Face Recognition\u200e',
#     'gl_class': 'IN05',
#     'heig': '\u200e157\u200e.60\u200e mm ( \u200e6\u200e.20\u200e in )\u200e',
#     'item_classification': 'ECA',
#     'item_number': '16-SMG975FZGDKRA',
#     'item_prefix': '16-',
#     'model': '\u200eجالكسي اس 10 بلس بشريحتين\u200e',
#     'mpn': 'SMG975FZGDKRA',
#     'port': '\u200eUSB\u200e-\u200eC\u200e/\u200e3\u200e.5\u200e mm Audio Jack\u200e',
#     'productcode_description': 'هواتف ذكية مجددة',
#     'rnrm': '\u200e521802\u200e\u200e',
#     'addtocart': '1',
#     'discountable': '0',
#     'jarir_master_tag': '28',
#     'jarir_tag_one': '38',
#     'jarir_tag_two': None,
#     'jb_tax_class_code': 'KSAVAT5',
#     'priority_qty': None,
#     'priority_val': None,
#     'sens': '\u200eAccelerometer, Barometer, Gyro, Geomagnetic, Hall, HR, Light, Proximity\u200e',
#     'serial_required': 'N',
#     'uom': 'Each',
#     'uom_code': 'EA',
#     'uom_desc': 'Each',
#     'video_url': None,
#     'weig': '\u200e175\u200e.00\u200e g ( \u200e6\u200e.18\u200e oz )\u200e',
#     'weight_uom': 'KG',
#     'widt': '\u200e74\u200e.10\u200e mm ( \u200e2\u200e.92\u200e in )\u200e',
#     'naming_formula': 'arabicname_field1*arabicname_field2*arabicname_field3*arabicname_field4*arabicname_field5*arabicname_field6',
#     'item_warranty_code': '16-ASP06Y2',
#     'family_code': 'RPALOS',
#     'before_addtocart_popup_block': None,
#     'below_pdp_image_block': None,
#     'how_to_content_block': None,
#     'how_to_content_popup_block': None,
#     'popup_block': None,
#     'incomplete_status_changed_kuwait': None,
#     'incomplete_status_changed_saudi': None,
#     'tamara_category': 'Category 3',
#     'renewed_oos_status_changed_saudi': None,
#     'description': 'default',
#     'short_description': 'GALAXY S10 PLUS DUAL 128GB GRE EN',
#     'meta_keyword': 'منتج مجدد درجة أ,سامسونج, سامسونج) جالكسي أس),أخضر زجاجي,4G LTE,SMG975FZGDKRA,مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات',
#     'additional_information': None,
#     'suggested_accessories': [{'title': {'en_US': 'Smartwatch',
#        'ar_SA': 'ساعةذكية'},
#       'skus': '532373',
#       'updated_on': '2021-12-02 09:08:11',
#       'action_hash': '10505c66c5ff44ff951b99f4911c976b'},
#      {'title': {'en_US': 'Other Smartphone Accessories',
#        'ar_SA': 'لوازم الهواتف الذكية'},
#       'skus': '531430,559600,559606',
#       'updated_on': '2021-12-08 01:35:06',
#       'action_hash': '580fab1ea45731b7586d8221f68c601d'}],
#     'producttag_data': None,
#     'alternative_item': '579022',
#     'klevu_search_keywords': 'Renewed Grade A, Samsung Galaxy S10+ (DUOS), 128 GB, Prism Green, 4G LTE, Smartphone',
#     'bought_together': '568437,568435,552857,560477,565161,581939,568477,581801,565160,567804',
#     'price': 3941.76,
#     'special_price': 1919,
#     'weight': 0.45,
#     'max_sale_qty': 5,
#     'min_sale_qty': 1,
#     'qty_increments': 1,
#     'price_ex_tax': 3427.6174,
#     'final_price_ex_tax': 1668.6957,
#     'jb_discount_percentage': 51,
#     'promotion_value': 2022.76,
#     'product_save': 2022.76,
#     'special_price_ex_vat': 1668.7,
#     'base_price_ex_vat': None,
#     'jarir_final_price': 1919,
#     'special_from_date': '2022-10-04 00:00:00',
#     'special_to_date': '2022-10-05 00:00:00',
#     'jb_product_update_at': '2022-10-03 20:12:19',
#     'status': 1,
#     'visibility': 4,
#     'tax_class_id': 0,
#     'priority': 552160,
#     'customer_limit': 0,
#     'cashoncollection_enable': 1,
#     'cod_enable': 1,
#     'pay_at_store': 1,
#     'showroom_collection': 1,
#     'homedelivery_enable': 1,
#     'international_shipping': '0',
#     'acce': 'Wireless Charging Pad/Power Bank Charger/Gimbal Stabilizer',
#     'apst': None,
#     'baca': '4100 mAh',
#     'baty': 'بطارية ليثيوم أيون',
#     'cars': 'الخلفية: 16 + 12 + 12 ميجابيكسل، الامامية 10 ميجابيكسل',
#     'chip': 'اكسينوس  9820',
#     'cofa': '49816',
#     'colo': '67944',
#     'cote': 'بلوتوث - واي فاي',
#     'cpuf': 'ام 4 مونجوز + كورتيكس ايه 75 + كورتكس  ايه 55',
#     'dipr': 'كورنينج غوريلا جلاس 6',
#     'exsl': 'ميكرو اس دي، ميكرو اس دي اتش سي، ميكرو اس دي اكس سي - حتى 512 جيجابايت',
#     'fing': 'نعم',
#     'flty': 'نعم',
#     'gpss': 'نعم',
#     'gpuf': 'ARM Mali-G76 MP12',
#     'moos': None,
#     'mxrs': '3040 بيكسل x 1440',
#     'nesu': '4G LTE',
#     'nfcf': None,
#     'nsim': 'شريحة ثنائية (هجين)',
#     'opsy': 'أندرويد 9.0 باي',
#     'prsd': '2.73 + 2.31 + 1.95 GHz',
#     'ptyp': 'هاتف ذكي',
#     'quch': 'شحن سريع للبطارية',
#     'reba': 'لا ينطبق',
#     'rnwg': '\u200eمنتج مجدد درجة أ\u200e',
#     'scsz': '6.4 بوصة',
#     'scty': 'ديناميك اموليد',
#     'seri': ' سامسونج) جالكسي أس)',
#     'sity': '(شريحة نانو (صغيرة',
#     'symm': '8 جيجابايت رام',
#     'tsca': None,
#     'vicr': '2160p@60fps',
#     'check_availability_status': 1,
#     'disabled_item_visibility': None,
#     'manual_sugg_accs': None,
#     'klevu_stock_flag': 0,
#     'tamara_enable': 1,
#     'is_showroom_delivery': True,
#     'jarir_cofa': 'اخضر',
#     'jarir_colo': 'أخضر زجاجي',
#     'slug': 'samsung-galaxy-s10-dual-renewed-smartphones-542550',
#     'url_path': 'samsung-galaxy-s10-dual-renewed-smartphones-542550.html',
#     'small_image': 'm1images/5/4/542550.jpg',
#     'image': 'm1images/5/4/542550.jpg',
#     'thumbnail': 'm1images/5/4/542550.jpg',
#     'gift_item_count': 0,
#     'jarir_mega_discount': '51%',
#     'product_description_url': 'https://vsf.jarir.com/productdescription?sku=542550',
#     'display_button': 'NO_BUTTON',
#     'category': [{'category_id': 1008,
#       'name': 'الهواتف الذكية',
#       'position': 11,
#       'level': 2},
#      {'category_id': 1017, 'name': 'سامسونج', 'position': 14, 'level': 3},
#      {'category_id': 1029,
#       'name': 'الهواتف الذكية',
#       'position': 19,
#       'level': 3},
#      {'category_id': 5, 'name': 'Default Category', 'position': 1, 'level': 1},
#      {'category_id': 1180,
#       'name': 'العروض الأسبوعية',
#       'position': 22,
#       'level': 2},
#      {'category_id': 1025, 'name': 'أفضل العروض', 'position': 22, 'level': 3},
#      {'category_id': 1733, 'name': 'أفضل العروض', 'position': 66, 'level': 2}],
#     'category_ids': [1008, 1017, 1029, 5, 1180, 1025, 1733],
#     'final_price': 1919,
#     'regular_price': 3941.76,
#     'product_links': [],
#     'configurable_children': [],
#     'parent_sku': [],
#     'brands_data': {'code': 'samsung',
#      'content_provider': 'flixmedia',
#      'image': 'b/4/c/a/b4cad588bc79e450085462601d5b7a08766815ab_samsung.png',
#      'label': 'سامسونج',
#      'id': 2245,
#      'tsk': 1664864066,
#      'label_translation': 'Samsung'}},
#    'sort': [552160]}},
#  {'link': '/api/catalogv1/product/store/sa-ar/category_ids/1008/aggregation/true/size/12/from/{}/sort-priority/asc',
#   'object': {'_index': 'vue_storefront_catalog_sa_ar_2022-10-04',
#    '_type': 'product',
#    '_id': '432008',
#    '_score': None,
#    '_source': {'attribute_set_id': 423,
#     'created_at': '2021-11-28 09:35:09',
#     'updated_at': '2022-10-04 04:12:35',
#     'type_id': 'simple',
#     'sku': '542864',
#     'id': 432008,
#     'media_gallery': [{'type': 'image',
#       'image': 'm1images/5/4/542864.jpg',
#       'lab': '',
#       'pos': 0}],
#     'tsk': 1664864066,
#     'name': '\u200e4\u200eG LTE ,رمادي فلكي ,\u200e512\u200e GB ,\u200e ايفون 11 برو ماكس\u200e \u200eابل\u200e منتج مجدد درجة أ\u200e',
#     'meta_title': 'ابل آبل آيفون 11 رمادي فلكي منتج مجدد درجة أ في مكتبة جرير السعودية اونلاين',
#     'meta_description': 'اشتر منتج مجدد درجة أ ابل آبل آيفون 11 رمادي فلكي 4G LTE smartphone في مكتبة جرير لأفضل العروض و الأسعار في الدمام، الرياض، جدة، السعودية. قارن الخصائص، المواصفات للتسوق اونلاين على موقع مكتبة جرير jarir.com',
#     'url_key': 'apple-iphone-11-pro-max-renewed-smartphones-542864',
#     'is_returnable': True,
#     'fulfilment_type': 'LIVE',
#     'fulfilment_method': 'NORMAL',
#     'is_cashback': True,
#     'arabicname_field1': '\u200eمنتج مجدد درجة أ\u200e',
#     'arabicname_field2': '\u200e\u200eابل\u200e\u200e',
#     'arabicname_field3': '\u200e\u200e ايفون 11 برو ماكس\u200e\u200e',
#     'arabicname_field4': '\u200e512\u200e GB\u200e',
#     'arabicname_field5': '\u200eرمادي فلكي\u200e',
#     'arabicname_field6': '\u200e4\u200eG LTE\u200e',
#     'bar_code1': None,
#     'bar_code2': None,
#     'box_height': '6.00',
#     'box_length': '18.00',
#     'box_width': '10.00',
#     'brand': 'ابل',
#     'cazo': None,
#     'dept': '\u200e.81\u200e cm ( .32\u200e in )\u200e',
#     'dim_uom': 'CM',
#     'feat': '\u200eSplash, Dust and Water Resistant\u200e',
#     'gl_class': 'IN05',
#     'heig': '\u200e15\u200e.80\u200e cm ( \u200e6\u200e.22\u200e in )\u200e',
#     'item_classification': 'ECA',
#     'item_number': '25-MWHN2AHARA',
#     'item_prefix': '25-',
#     'model': '\u200e ايفون 11 برو ماكس\u200e',
#     'mpn': 'MWHN2AHA',
#     'port': '\u200eلايتنينج\u200e',
#     'productcode_description': 'هواتف ذكية مجددة',
#     'rnrm': '\u200e534368\u200e\u200e',
#     'addtocart': '1',
#     'discountable': '0',
#     'jarir_master_tag': '28',
#     'jarir_tag_one': '38',
#     'jarir_tag_two': None,
#     'jb_tax_class_code': 'KSAVAT5',
#     'priority_qty': None,
#     'priority_val': None,
#     'sens': '\u200eFace ID, Barometer, Three\u200e-\u200eaxis Gyro, Accelerometer, Proximity, Ambient Light\u200e',
#     'serial_required': 'N',
#     'uom': 'Each',
#     'uom_code': 'EA',
#     'uom_desc': 'Each',
#     'video_url': None,
#     'weig': '\u200e22. كجم\u200e',
#     'weight_uom': 'KG',
#     'widt': '\u200e7\u200e.78\u200e cm ( \u200e3\u200e.06\u200e in )\u200e',
#     'naming_formula': 'arabicname_field1*arabicname_field2*arabicname_field3*arabicname_field4*arabicname_field5*arabicname_field6',
#     'item_warranty_code': '25-ASP12Y2',
#     'family_code': 'RPALOS',
#     'before_addtocart_popup_block': None,
#     'below_pdp_image_block': None,
#     'how_to_content_block': None,
#     'how_to_content_popup_block': None,
#     'popup_block': None,
#     'incomplete_status_changed_kuwait': None,
#     'incomplete_status_changed_saudi': None,
#     'tamara_category': 'Category 3',
#     'renewed_oos_status_changed_saudi': None,
#     'description': 'default',
#     'short_description': 'IPHONE 11 PRO MAX 512GB SPACE GREY',
#     'meta_keyword': 'منتج مجدد درجة أ,ابل,آبل آيفون 11,رمادي فلكي,4G LTE,MWHN2AHA,مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات',
#     'additional_information': None,
#     'suggested_accessories': [{'title': {'en_US': 'Smartwatch',
#        'ar_SA': 'ساعةذكية'},
#       'skus': '526831,526832,526833,526834,526877,535673,536222',
#       'updated_on': '2021-12-02 09:08:11',
#       'action_hash': '10505c66c5ff44ff951b99f4911c976b'},
#      {'title': {'en_US': 'Other Smartphone Accessories',
#        'ar_SA': 'لوازم الهواتف الذكية'},
#       'skus': '531430,559600,559606',
#       'updated_on': '2021-12-08 01:35:06',
#       'action_hash': '580fab1ea45731b7586d8221f68c601d'}],
#     'producttag_data': None,
#     'alternative_item': None,
#     'klevu_search_keywords': 'Renewed Grade A, Apple iPhone 11 Pro Max, 512 GB, Space Grey, 4G LTE, Smartphone',
#     'bought_together': '467294,556835,571566,516647,526254,571568,571546,548778,563729,514028',
#     'price': 6898.9,
#     'special_price': 5039,
#     'weight': 0.58,
#     'max_sale_qty': 5,
#     'min_sale_qty': 1,
#     'qty_increments': 1,
#     'price_ex_tax': 5999.0435,
#     'final_price_ex_tax': 4381.7391,
#     'jb_discount_percentage': 26,
#     'promotion_value': 1859.9,
#     'product_save': 1859.9,
#     'special_price_ex_vat': 4381.74,
#     'base_price_ex_vat': None,
#     'jarir_final_price': 5039,
#     'special_from_date': '2022-10-04 00:00:00',
#     'special_to_date': '2022-10-05 00:00:00',
#     'jb_product_update_at': '2022-10-03 20:12:19',
#     'status': 1,
#     'visibility': 4,
#     'tax_class_id': 0,
#     'priority': 552225,
#     'customer_limit': 0,
#     'cashoncollection_enable': 1,
#     'cod_enable': 1,
#     'pay_at_store': 1,
#     'showroom_collection': 1,
#     'homedelivery_enable': 1,
#     'international_shipping': '0',
#     'acce': 'iPhone Car Charger/Wireless Charging Pad/Power Bank Charger/Gimbal Stabilizer',
#     'apst': None,
#     'baca': 'لا ينطبق',
#     'baty': 'بطارية ليثيوم أيون',
#     'cars': 'الخلفية: 12 + 12 + 12 ميجابيكسل، الامامية 12 ميجابيكسل',
#     'chip': 'آبل أيه 13 بايونيك',
#     'cofa': '49817',
#     'colo': '68292',
#     'cote': '(أن أف سي (آبل باي/واي فاي/بلوتوث',
#     'cpuf': 'لا ينطبق',
#     'dipr': 'لا ينطبق',
#     'exsl': 'لا ينطبق',
#     'fing': 'لا ينطبق',
#     'flty': 'نعم',
#     'gpss': 'نعم',
#     'gpuf': 'لا ينطبق',
#     'moos': None,
#     'mxrs': '1242 × 2688 بيكسل',
#     'nesu': '4G LTE',
#     'nfcf': None,
#     'nsim': 'Dual SIM (nano-SIM/eSIM)',
#     'opsy': 'iOS 13',
#     'prsd': 'لا ينطبق',
#     'ptyp': 'هاتف ذكي',
#     'quch': 'شحن سريع للبطارية',
#     'reba': 'لا ينطبق',
#     'rnwg': '\u200eمنتج مجدد درجة أ\u200e',
#     'scsz': '6.5 بوصة',
#     'scty': 'شاشة اكس دي آر سوبر ريتنا',
#     'seri': 'آبل آيفون 11',
#     'sity': 'شريحة 2: الكترونية / شريحة 1: نانو',
#     'symm': 'لا ينطبق',
#     'tsca': None,
#     'vicr': '4K Recording at 24fps, 30fps, or 60fps',
#     'check_availability_status': 1,
#     'disabled_item_visibility': None,
#     'manual_sugg_accs': None,
#     'klevu_stock_flag': 0,
#     'tamara_enable': 0,
#     'is_showroom_delivery': True,
#     'jarir_cofa': 'رمادي',
#     'jarir_colo': 'رمادي فلكي',
#     'slug': 'apple-iphone-11-pro-max-renewed-smartphones-542864',
#     'url_path': 'apple-iphone-11-pro-max-renewed-smartphones-542864.html',
#     'small_image': 'm1images/5/4/542864.jpg',
#     'image': 'm1images/5/4/542864.jpg',
#     'thumbnail': 'm1images/5/4/542864.jpg',
#     'gift_item_count': 0,
#     'jarir_mega_discount': '27%',
#     'product_description_url': 'https://vsf.jarir.com/productdescription?sku=542864',
#     'display_button': 'NO_BUTTON',
#     'category': [{'category_id': 1008,
#       'name': 'الهواتف الذكية',
#       'position': 11,
#       'level': 2},
#      {'category_id': 1010, 'name': 'ابل', 'position': 2, 'level': 3},
#      {'category_id': 1029,
#       'name': 'الهواتف الذكية',
#       'position': 19,
#       'level': 3},
#      {'category_id': 5, 'name': 'Default Category', 'position': 1, 'level': 1},
#      {'category_id': 1038, 'name': 'آيفون', 'position': 30, 'level': 3},
#      {'category_id': 1180,
#       'name': 'العروض الأسبوعية',
#       'position': 22,
#       'level': 2},
#      {'category_id': 1025, 'name': 'أفضل العروض', 'position': 22, 'level': 3},
#      {'category_id': 1733, 'name': 'أفضل العروض', 'position': 66, 'level': 2}],
#     'category_ids': [1008, 1010, 1029, 5, 1038, 1180, 1025, 1733],
#     'final_price': 5039,
#     'regular_price': 6898.9,
#     'product_links': [],
#     'configurable_children': [],
#     'parent_sku': [],
#     'brands_data': {'code': 'apple',
#      'content_provider': 'cnet',
#      'image': 'c/9/8/4/c98436b347e124454f5f19cfc60e5ad811c91d8c_apple.png',
#      'label': 'ابل',
#      'id': 175,
#      'tsk': 1664864066,
#      'label_translation': 'Apple'}},
#    'sort': [552225]}},
#  {'link': '/api/catalogv1/product/store/sa-ar/category_ids/1008/aggregation/true/size/12/from/{}/sort-priority/asc',
#   'object': {'_index': 'vue_storefront_catalog_sa_ar_2022-10-04',
#    '_type': 'product',
#    '_id': '432009',
#    '_score': None,
#    '_source': {'attribute_set_id': 423,
#     'created_at': '2021-11-28 09:35:09',
#     'updated_at': '2022-10-04 04:12:35',
#     'type_id': 'simple',
#     'sku': '542866',
#     'id': 432009,
#     'media_gallery': [{'type': 'image',
#       'image': 'm1images/5/4/542866.jpg',
#       'lab': '',
#       'pos': 0}],
#     'tsk': 1664864066,
#     'name': '\u200e4\u200eG LTE ,فضي ,\u200e512\u200e GB ,\u200e ايفون 11 برو ماكس\u200e \u200eابل\u200e منتج مجدد درجة أ\u200e',
#     'meta_title': 'ابل آبل آيفون 11 فضي منتج مجدد درجة أ في مكتبة جرير السعودية اونلاين',
#     'meta_description': 'اشتر منتج مجدد درجة أ ابل آبل آيفون 11 فضي 4G LTE smartphone في مكتبة جرير لأفضل العروض و الأسعار في الدمام، الرياض، جدة، السعودية. قارن الخصائص، المواصفات للتسوق اونلاين على موقع مكتبة جرير jarir.com',
#     'url_key': 'apple-iphone-11-pro-max-renewed-smartphones-542866',
#     'is_returnable': True,
#     'fulfilment_type': 'LIVE',
#     'fulfilment_method': 'NORMAL',
#     'is_cashback': True,
#     'arabicname_field1': '\u200eمنتج مجدد درجة أ\u200e',
#     'arabicname_field2': '\u200e\u200eابل\u200e\u200e',
#     'arabicname_field3': '\u200e\u200e ايفون 11 برو ماكس\u200e\u200e',
#     'arabicname_field4': '\u200e512\u200e GB\u200e',
#     'arabicname_field5': '\u200eفضي\u200e',
#     'arabicname_field6': '\u200e4\u200eG LTE\u200e',
#     'bar_code1': None,
#     'bar_code2': None,
#     'box_height': '6.00',
#     'box_length': '18.00',
#     'box_width': '10.00',
#     'brand': 'ابل',
#     'cazo': None,
#     'dept': '\u200e.81\u200e cm ( .32\u200e in )\u200e',
#     'dim_uom': 'CM',
#     'feat': '\u200eSplash, Dust and Water Resistant\u200e',
#     'gl_class': 'IN05',
#     'heig': '\u200e15\u200e.80\u200e cm ( \u200e6\u200e.22\u200e in )\u200e',
#     'item_classification': 'ECA',
#     'item_number': '25-MWHP2AHARA',
#     'item_prefix': '25-',
#     'model': '\u200e ايفون 11 برو ماكس\u200e',
#     'mpn': 'MWHP2AHA',
#     'port': '\u200eلايتنينج\u200e',
#     'productcode_description': 'هواتف ذكية مجددة',
#     'rnrm': '\u200e534372\u200e\u200e',
#     'addtocart': '1',
#     'discountable': '0',
#     'jarir_master_tag': '28',
#     'jarir_tag_one': '38',
#     'jarir_tag_two': None,
#     'jb_tax_class_code': 'KSAVAT5',
#     'priority_qty': None,
#     'priority_val': None,
#     'sens': '\u200eFace ID, Barometer, Three\u200e-\u200eaxis Gyro, Accelerometer, Proximity, Ambient Light\u200e',
#     'serial_required': 'N',
#     'uom': 'Each',
#     'uom_code': 'EA',
#     'uom_desc': 'Each',
#     'video_url': None,
#     'weig': '\u200e22. كجم\u200e',
#     'weight_uom': 'KG',
#     'widt': '\u200e7\u200e.78\u200e cm ( \u200e3\u200e.06\u200e in )\u200e',
#     'naming_formula': 'arabicname_field1*arabicname_field2*arabicname_field3*arabicname_field4*arabicname_field5*arabicname_field6',
#     'item_warranty_code': '25-ASP12Y2',
#     'family_code': 'RPALOS',
#     'before_addtocart_popup_block': None,
#     'below_pdp_image_block': None,
#     'how_to_content_block': None,
#     'how_to_content_popup_block': None,
#     'popup_block': None,
#     'incomplete_status_changed_kuwait': None,
#     'incomplete_status_changed_saudi': None,
#     'tamara_category': 'Category 3',
#     'renewed_oos_status_changed_saudi': None,
#     'description': 'default',
#     'short_description': 'IPHONE 11 PRO MAX 512GB SILVER',
#     'meta_keyword': 'منتج مجدد درجة أ,ابل,آبل آيفون 11,فضي,4G LTE,MWHP2AHA,مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات',
#     'additional_information': None,
#     'suggested_accessories': [{'title': {'en_US': 'Smartwatch',
#        'ar_SA': 'ساعةذكية'},
#       'skus': '526831,526832,526833,526834,526877,535673,536222',
#       'updated_on': '2021-12-02 09:08:11',
#       'action_hash': '10505c66c5ff44ff951b99f4911c976b'},
#      {'title': {'en_US': 'Other Smartphone Accessories',
#        'ar_SA': 'لوازم الهواتف الذكية'},
#       'skus': '531430,559600,559606',
#       'updated_on': '2021-12-08 01:35:06',
#       'action_hash': '580fab1ea45731b7586d8221f68c601d'}],
#     'producttag_data': None,
#     'alternative_item': None,
#     'klevu_search_keywords': 'Renewed Grade A, Apple iPhone 11 Pro Max, 512 GB, Silver, 4G LTE, Smartphone',
#     'bought_together': '467294,556835,571566,516647,526254,571568,571546,548778,563729,514028',
#     'price': 6898.9,
#     'special_price': 5039,
#     'weight': 0.58,
#     'max_sale_qty': 5,
#     'min_sale_qty': 1,
#     'qty_increments': 1,
#     'price_ex_tax': 5999.0435,
#     'final_price_ex_tax': 4381.7391,
#     'jb_discount_percentage': 26,
#     'promotion_value': 1859.9,
#     'product_save': 1859.9,
#     'special_price_ex_vat': 4381.74,
#     'base_price_ex_vat': None,
#     'jarir_final_price': 5039,
#     'special_from_date': '2022-10-04 00:00:00',
#     'special_to_date': '2022-10-05 00:00:00',
#     'jb_product_update_at': '2022-10-03 20:12:19',
#     'status': 1,
#     'visibility': 4,
#     'tax_class_id': 0,
#     'priority': 552230,
#     'customer_limit': 0,
#     'cashoncollection_enable': 1,
#     'cod_enable': 1,
#     'pay_at_store': 1,
#     'showroom_collection': 1,
#     'homedelivery_enable': 1,
#     'international_shipping': '0',
#     'acce': 'iPhone Car Charger/Wireless Charging Pad/Power Bank Charger/Gimbal Stabilizer',
#     'apst': None,
#     'baca': 'لا ينطبق',
#     'baty': 'بطارية ليثيوم أيون',
#     'cars': 'الخلفية: 12 + 12 + 12 ميجابيكسل، الامامية 12 ميجابيكسل',
#     'chip': 'آبل أيه 13 بايونيك',
#     'cofa': '49822',
#     'colo': '68207',
#     'cote': '(أن أف سي (آبل باي/واي فاي/بلوتوث',
#     'cpuf': 'لا ينطبق',
#     'dipr': 'لا ينطبق',
#     'exsl': 'لا ينطبق',
#     'fing': 'لا ينطبق',
#     'flty': 'نعم',
#     'gpss': 'نعم',
#     'gpuf': 'لا ينطبق',
#     'moos': None,
#     'mxrs': '1242 × 2688 بيكسل',
#     'nesu': '4G LTE',
#     'nfcf': None,
#     'nsim': 'Dual SIM (nano-SIM/eSIM)',
#     'opsy': 'iOS 13',
#     'prsd': 'لا ينطبق',
#     'ptyp': 'هاتف ذكي',
#     'quch': 'شحن سريع للبطارية',
#     'reba': 'لا ينطبق',
#     'rnwg': '\u200eمنتج مجدد درجة أ\u200e',
#     'scsz': '6.5 بوصة',
#     'scty': 'شاشة اكس دي آر سوبر ريتنا',
#     'seri': 'آبل آيفون 11',
#     'sity': 'شريحة 2: الكترونية / شريحة 1: نانو',
#     'symm': 'لا ينطبق',
#     'tsca': None,
#     'vicr': '4K Recording at 24fps, 30fps, or 60fps',
#     'check_availability_status': 1,
#     'disabled_item_visibility': None,
#     'manual_sugg_accs': None,
#     'klevu_stock_flag': 0,
#     'tamara_enable': 0,
#     'is_showroom_delivery': True,
#     'jarir_cofa': 'فضي',
#     'jarir_colo': 'فضي',
#     'slug': 'apple-iphone-11-pro-max-renewed-smartphones-542866',
#     'url_path': 'apple-iphone-11-pro-max-renewed-smartphones-542866.html',
#     'small_image': 'm1images/5/4/542866.jpg',
#     'image': 'm1images/5/4/542866.jpg',
#     'thumbnail': 'm1images/5/4/542866.jpg',
#     'gift_item_count': 0,
#     'jarir_mega_discount': '27%',
#     'product_description_url': 'https://vsf.jarir.com/productdescription?sku=542866',
#     'display_button': 'NO_BUTTON',
#     'category': [{'category_id': 1008,
#       'name': 'الهواتف الذكية',
#       'position': 11,
# ...
#       'jarir_colo': 'اخضر',
#       'media_gallery': [{'type': 'image',
#         'image': 'm1/delta/557627.jpg',
#         'lab': '',
#         'pos': 0},
#        {'type': 'image',
#         'image': 'm1/delta/557627_1.jpg',
#         'lab': '',
#         'pos': 1},
#        {'type': 'image',
#         'image': 'm1/delta/557627_2.jpg',
#         'lab': '',
#         'pos': 2},
#        {'type': 'image',
#         'image': 'm1/delta/557627_3.jpg',
#         'lab': '',
#         'pos': 3}],
#       'id': 270746,
#       'stock': {'is_in_stock': False,
#        'min_qty': 0,
#        'notify_stock_qty': 1,
#        'use_config_notify_stock_qty': True,
#        'qty': 0,
#        'stock_status': 1},
#       'display_button': 'NO_BUTTON'},
#      {'sku': '585913',
#       'final_price': 1949,
#       'regular_price': 2099,
#       'name': '\u200eآبل أيه 13 بايونيك ,\u200e4\u200eG LTE أصفر ,\u200e64\u200e GB ,\u200eايفون 11\u200e \u200eابل\u200e\u200e',
#       'meta_title': 'ابل آبل آيفون 11 64 GB أصفر في مكتبة جرير السعودية اونلاين',
#       'meta_description': 'اشتر ابل آبل آيفون 11 64 GB أصفر 4G LTE هاتف ذكي في مكتبة جرير لأفضل العروض و الأسعار في الدمام، الرياض، جدة، السعودية. قارن الخصائص، المواصفات للتسوق اونلاين على موقع مكتبة جرير jarir.com',
#       'url_key': 'apple-iphone-11-smartphones-585913',
#       'is_returnable': True,
#       'protection_service_sku': '556614',
#       'fulfilment_type': 'LIVE',
#       'fulfilment_method': 'NORMAL',
#       'is_cashback': True,
#       'arabicname_field1': '\u200e\u200eابل\u200e\u200e',
#       'arabicname_field2': '\u200e\u200eايفون 11\u200e\u200e',
#       'arabicname_field3': '\u200e64\u200e GB\u200e',
#       'arabicname_field4': '\u200eأصفر\u200e',
#       'arabicname_field5': '\u200e4\u200eG LTE\u200e',
#       'arabicname_field6': '\u200eآبل أيه 13 بايونيك\u200e',
#       'arabicname_field7': None,
#       'bar_code1': '194252098004',
#       'bar_code2': '194252098004',
#       'box_height': '7.00',
#       'box_length': '17.00',
#       'box_width': '10.00',
#       'brand': 'Apple',
#       'cancellation_policy': None,
#       'cazo': '\u200e2\u200eX Optical Zoom;Digital Zoom up to \u200e5\u200eX, Ultra Wide\u200e/\u200eWide Camera, Advance Bokeh\u200e',
#       'dept': '\u200e83. سم\u200e',
#       'dim_uom': 'CM',
#       'feat': '\u200eمقاوم للماء والغبار\u200e',
#       'gl_class': 'IN05',
#       'heig': '\u200e15.00 سم\u200e',
#       'item_classification': 'ECA',
#       'item_number': '25-MHDE3AAA',
#       'item_prefix': '25-',
#       'model': '\u200eايفون 11\u200e',
#       'mpn': 'MHDE3AAA',
#       'port': '\u200eلايتنينج\u200e',
#       'productcode_description': 'الهواتف الذكية',
#       'addtocart': '1',
#       'discountable': '0',
#       'jarir_master_tag': '28',
#       'jarir_tag_one': None,
#       'jarir_tag_three': None,
#       'jarir_tag_two': None,
#       'jb_tax_class_code': 'KSAVAT5',
#       'priority_qty': None,
#       'priority_val': None,
#       'sku_remarks_title': None,
#       'sens': '\u200eFace ID, Barometer, Three\u200e-\u200eaxis Gyro\u200e',
#       'serial_required': 'Y',
#       'uom': 'Each',
#       'uom_code': 'EA',
#       'uom_desc': 'Each',
#       'video_url': 'https://www.youtube.com/embed/zB3KJEPUAnA?rel=0',
#       'weig': '\u200e19. كجم\u200e',
#       'weight_uom': 'KG',
#       'widt': '\u200e7.57 سم\u200e',
#       'naming_formula': 'arabicname_field1*arabicname_field2*arabicname_field3*arabicname_field4*arabicname_field5*arabicname_field6',
#       'item_warranty_code': '25-ASP12Y2',
#       'family_code': 'FPALOS',
#       'before_addtocart_popup_block': None,
#       'below_pdp_image_block': None,
#       'how_to_content_block': None,
#       'how_to_content_popup_block': None,
#       'popup_block': None,
#       'parent_url_key': 'apple-iphone-11-smartphones-jpm1',
#       'akeneo_image': 'c/8/0/9/c8098e4949bad6dfcb38aa6ad384c8dba778bb8a_585913.jpg',
#       'incomplete_status_changed_kuwait': None,
#       'incomplete_status_changed_saudi': None,
#       'tamara_category': 'Category 3',
#       'description': 'default',
#       'short_description': 'IPHONE 11 64GB YELLOW',
#       'meta_keyword': 'ابل,آبل آيفون 11,MHDE3AAA,64 GB,أصفر,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي',
#       'additional_information': '<p><img class="img-responsive" src="https://www.jarir.com/media/wysiwyg/Saudi/LP/iphone11-landing-page-en.jpg" alt="" /></p> ',
#       'sku_remarks_body': None,
#       'suggested_accessories': [{'title': {'en_US': 'Essentials',
#          'ar_SA': 'الأساسيات'},
#         'skus': '556835,534362,526254,467294,402208',
#         'updated_on': '2022-04-26 12:00:05',
#         'action_hash': 'manual update'}],
#       'producttag_data': None,
#       'alternative_item': '585914,557623,557621,557620,557626,569416,557627,569419,569408,581932,569327,569414,556815,569307,569289,557624,569418,569270,569313,569276,569306,569322,581926,569279,581896',
#       'klevu_search_keywords': 'Apple iPhone 11, 64 GB, 4G LTE, Yellow',
#       'bought_together': None,
#       'price': 2099,
#       'special_price': 1949,
#       'weight': None,
#       'max_sale_qty': 2,
#       'min_sale_qty': 1,
#       'qty_increments': 1,
#       'price_ex_tax': 1825.2174,
#       'final_price_ex_tax': 1694.7826,
#       'promotion_value': 150,
#       'product_save': 150,
#       'special_price_ex_vat': 1694.79,
#       'base_price_ex_vat': 1825.21,
#       'jarir_final_price': 1949,
#       'special_from_date': '2022-10-04 00:00:00',
#       'special_to_date': '2022-10-05 00:00:00',
#       'jb_product_update_at': '2022-10-03 20:14:06',
#       'status': 1,
#       'visibility': 1,
#       'tax_class_id': 0,
#       'priority': 554595,
#       'is_protection_service': False,
#       'customer_limit': 1,
#       'cashoncollection_enable': 1,
#       'cod_enable': 1,
#       'pay_at_store': 1,
#       'showroom_collection': 1,
#       'homedelivery_enable': 1,
#       'international_shipping': '0',
#       'acce': 'iPhone Car Charger/Power Bank Charger/Gimbal Stabilizer/Health and Personal Car',
#       'apst': 'متجر تطبيقات آبل',
#       'auja': 'Lightning',
#       'baca': 'لا ينطبق',
#       'baty': 'لا ينطبق',
#       'capa': '47665',
#       'cars': 'الخلفية: 12 + 12 ميجابيكسل، الامامية 12 ميجابيكسل',
#       'chip': 'آبل أيه 13 بايونيك',
#       'chme': 'شاحن لاسلكي/سلكي',
#       'cofa': '49824',
#       'colo': '68683',
#       'core': 'لا ينطبق',
#       'cote': 'بلوتوث - واي فاي',
#       'cpuf': 'لا ينطبق',
#       'dipr': 'طبقة مقاومة للبصمات',
#       'exsl': 'لا ينطبق',
#       'fing': 'لا ينطبق',
#       'flty': 'نعم',
#       'gpss': 'نعم',
#       'gpuf': 'لا ينطبق',
#       'moos': ' آي أو اس',
#       'mxca': '12 ميجابيكسل',
#       'mxrs': '828 × 1792 بيكسل',
#       'nesu': '4G LTE',
#       'nfcf': 'نعم',
#       'nsim': 'Dual SIM (nano-SIM/eSIM)',
#       'opsy': 'iOS 13',
#       'prsd': 'لا ينطبق',
#       'ptyp': 'هاتف ذكي',
#       'quch': 'شحن سريع للبطارية',
#       'reba': 'لا ينطبق',
#       'scsz': '6.1 بوصة',
#       'scty': 'شاشة ليكويد ريتنا اتش دي',
#       'seri': 'آبل آيفون 11',
#       'sity': 'شريحة 2: الكترونية / شريحة 1: نانو',
#       'symm': 'لا ينطبق',
#       'tsca': '128 جيجابايت',
#       'vicr': '4K Recording at 24fps, 30fps, or 60fps',
#       'check_availability_status': 1,
#       'disabled_item_visibility': None,
#       'manual_sugg_accs': 1,
#       'klevu_stock_flag': 0,
#       'tamara_enable': 1,
#       'is_showroom_delivery': True,
#       'jarir_capa': '64 GB',
#       'jarir_cofa': 'أصفر',
#       'jarir_colo': 'أصفر',
#       'media_gallery': [{'type': 'image',
#         'image': 'c/8/0/9/c8098e4949bad6dfcb38aa6ad384c8dba778bb8a_585913.jpg',
#         'lab': '',
#         'pos': 0},
#        {'type': 'image',
#         'image': '4/8/b/6/48b6d11d780fe54dfc43083e13fa268f22b00382_585913_1.jpg',
#         'lab': '',
#         'pos': 1},
#        {'type': 'image',
#         'image': '6/5/f/7/65f71d97b789a11983a68deb4ed94fb9ec29b135_585913_2.jpg',
#         'lab': '',
#         'pos': 2},
#        {'type': 'image',
#         'image': '9/b/5/a/9b5a65297bd8ad61dba5700318c861481764ba4b_585913_3.jpg',
#         'lab': '',
#         'pos': 3}],
#       'id': 552443,
#       'stock': {'is_in_stock': False,
#        'min_qty': 0,
#        'notify_stock_qty': 1,
#        'use_config_notify_stock_qty': True,
#        'qty': 0,
#        'stock_status': 0},
#       'display_button': 'NO_BUTTON'},
#      {'sku': '585914',
#       'final_price': 2149,
#       'regular_price': 2299,
#       'name': '\u200eآبل أيه 13 بايونيك ,\u200e4\u200eG LTE سعة 128 جيجابايت, أصفر ,\u200eايفون 11\u200e \u200eابل\u200e\u200e',
#       'meta_title': 'ابل آبل آيفون 11 سعة 128 جيجابايت أصفر في مكتبة جرير السعودية اونلاين',
#       'meta_description': 'اشتر ابل آبل آيفون 11 سعة 128 جيجابايت أصفر 4G LTE هاتف ذكي في مكتبة جرير لأفضل العروض و الأسعار في الدمام، الرياض، جدة، السعودية. قارن الخصائص، المواصفات للتسوق اونلاين على موقع مكتبة جرير jarir.com',
#       'url_key': 'apple-smartphones-585914',
#       'is_returnable': True,
#       'protection_service_sku': '556615',
#       'fulfilment_type': 'LIVE',
#       'fulfilment_method': 'NORMAL',
#       'is_cashback': True,
#       'arabicname_field1': '\u200e\u200eابل\u200e\u200e',
#       'arabicname_field2': '\u200e\u200eايفون 11\u200e\u200e',
#       'arabicname_field3': '\u200eسعة 128 جيجابايت\u200e',
#       'arabicname_field4': '\u200eأصفر\u200e',
#       'arabicname_field5': '\u200e4\u200eG LTE\u200e',
#       'arabicname_field6': '\u200eآبل أيه 13 بايونيك\u200e',
#       'arabicname_field7': None,
#       'bar_code1': '25859140',
#       'bar_code2': '194252099865',
#       'box_height': '7.00',
#       'box_length': '17.00',
#       'box_width': '10.00',
#       'brand': 'Apple',
#       'cancellation_policy': None,
#       'cazo': '\u200e2\u200eX Optical Zoom;Digital Zoom up to \u200e5\u200eX, Ultra Wide\u200e/\u200eWide Camera, Advance Bokeh\u200e',
#       'dept': '\u200e83. سم\u200e',
#       'dim_uom': 'CM',
#       'feat': '\u200eمقاوم للماء والغبار\u200e',
#       'gl_class': 'IN05',
#       'heig': '\u200e15.00 سم\u200e',
#       'item_classification': 'ECA',
#       'item_number': '25-MHDL3AAA',
#       'item_prefix': '25-',
#       'model': '\u200eايفون 11\u200e',
#       'mpn': 'MHDL3AAA',
#       'port': '\u200eلايتنينج\u200e',
#       'productcode_description': 'الهواتف الذكية',
#       'addtocart': '1',
#       'discountable': '0',
#       'jarir_master_tag': '28',
#       'jarir_tag_one': None,
#       'jarir_tag_three': None,
#       'jarir_tag_two': None,
#       'jb_tax_class_code': 'KSAVAT5',
#       'priority_qty': None,
#       'priority_val': None,
#       'sku_remarks_title': None,
#       'sens': '\u200eFace ID, Barometer, Three\u200e-\u200eaxis Gyro\u200e',
#       'serial_required': 'Y',
#       'uom': 'Each',
#       'uom_code': 'EA',
#       'uom_desc': 'Each',
#       'video_url': 'https://www.youtube.com/embed/zB3KJEPUAnA?rel=0',
#       'weig': '\u200e19. كجم\u200e',
#       'weight_uom': 'KG',
#       'widt': '\u200e7.57 سم\u200e',
#       'naming_formula': 'arabicname_field1*arabicname_field2*arabicname_field3*arabicname_field4*arabicname_field5*arabicname_field6',
#       'item_warranty_code': '25-ASP12Y2',
#       'family_code': 'FPALOS',
#       'before_addtocart_popup_block': None,
#       'below_pdp_image_block': None,
#       'how_to_content_block': None,
#       'how_to_content_popup_block': None,
#       'popup_block': None,
#       'parent_url_key': 'apple-iphone-11-smartphones-jpm1',
#       'akeneo_image': '7/8/b/5/78b59a3cca1bd9b252d1a1803e11b7b3d3cbcb8d_585914.jpg',
#       'incomplete_status_changed_kuwait': None,
#       'incomplete_status_changed_saudi': None,
#       'tamara_category': 'Category 3',
#       'description': 'default',
#       'short_description': 'IPHONE 11 128GB YELLOW',
#       'meta_keyword': 'ابل,آبل آيفون 11,MHDL3AAA,سعة 128 جيجابايت,أصفر,4G LTE,ابل ايفون, سامسونج جالكسي, هواوي, شاومي, مكتبة جرير، تسوق أونلاين، عروض، خصائص، مواصفات, اوبو,فيفو,نوكيا,هاتف ذكي',
#       'additional_information': '<p><img class="img-responsive" src="https://www.jarir.com/media/wysiwyg/Saudi/LP/iphone11-landing-page-en.jpg" alt="" /></p> ',
#       'sku_remarks_body': None,
#       'suggested_accessories': [{'title': {'en_US': 'Essentials',
#          'ar_SA': 'الأساسيات'},
#         'skus': '556835,534362,526254,467294,402208',
#         'updated_on': '2022-04-26 12:00:05',
#         'action_hash': 'manual update'}],
#       'producttag_data': None,
#       'alternative_item': '557627,557626,557625,557624,569419,557620,581932,585913,556815,569289,569307,569276,569279,557623,569292,581908,556810,563746,563740,569408,569327,569414,569418,569306,569270',
#       'klevu_search_keywords': 'Apple 128 GB, 4G LTE, Yellow',
#       'bought_together': None,
#       'price': 2299,
#       'special_price': 2149,
#       'weight': None,
#       'max_sale_qty': 2,
#       'min_sale_qty': 1,
#       'qty_increments': 1,
#       'price_ex_tax': 1999.1304,
#       'final_price_ex_tax': 1868.6957,
#       'promotion_value': 150,
#       'product_save': 150,
#       'special_price_ex_vat': 1868.7,
#       'base_price_ex_vat': 1999.13,
#       'jarir_final_price': 2149,
#       'special_from_date': '2022-10-04 00:00:00',
#       'special_to_date': '2022-10-05 00:00:00',
#       'jb_product_update_at': '2022-10-03 20:14:06',
#       'status': 1,
#       'visibility': 1,
#       'tax_class_id': 0,
#       'priority': 554590,
#       'is_protection_service': False,
#       'customer_limit': 1,
#       'cashoncollection_enable': 1,
#       'cod_enable': 1,
#       'pay_at_store': 1,
#       'showroom_collection': 1,
#       'homedelivery_enable': 1,
#       'international_shipping': '0',
#       'acce': 'iPhone Car Charger/Power Bank Charger/Gimbal Stabilizer/Health and Personal Car',
#       'apst': 'متجر تطبيقات آبل',
#       'auja': 'Lightning',
#       'baca': 'لا ينطبق',
#       'baty': 'لا ينطبق',
#       'capa': '47467',
#       'cars': 'الخلفية: 12 + 12 ميجابيكسل، الامامية 12 ميجابيكسل',
#       'chip': 'آبل أيه 13 بايونيك',
#       'chme': 'شاحن لاسلكي/سلكي',
#       'cofa': '49824',
#       'colo': '68683',
#       'core': 'لا ينطبق',
#       'cote': 'بلوتوث - واي فاي',
#       'cpuf': 'لا ينطبق',
#       'dipr': 'طبقة مقاومة للبصمات',
#       'exsl': 'لا ينطبق',
#       'fing': 'لا ينطبق',
#       'flty': 'نعم',
#       'gpss': 'نعم',
#       'gpuf': 'لا ينطبق',
#       'moos': ' آي أو اس',
#       'mxca': '12 ميجابيكسل',
#       'mxrs': '828 × 1792 بيكسل',
#       'nesu': '4G LTE',
#       'nfcf': 'نعم',
#       'nsim': 'Dual SIM (nano-SIM/eSIM)',
#       'opsy': 'iOS 13',
#       'prsd': 'لا ينطبق',
#       'ptyp': 'هاتف ذكي',
#       'quch': 'شحن سريع للبطارية',
#       'reba': 'لا ينطبق',
#       'scsz': '6.1 بوصة',
#       'scty': 'شاشة ليكويد ريتنا اتش دي',
#       'seri': 'آبل آيفون 11',
#       'sity': 'شريحة 2: الكترونية / شريحة 1: نانو',
#       'symm': 'لا ينطبق',
#       'tsca': '128 جيجابايت',
#       'vicr': '4K Recording at 24fps, 30fps, or 60fps',
#       'check_availability_status': 1,
#       'disabled_item_visibility': None,
#       'manual_sugg_accs': 1,
#       'klevu_stock_flag': 0,
#       'tamara_enable': 1,
#       'is_showroom_delivery': True,
#       'jarir_capa': 'سعة 128 جيجابايت',
#       'jarir_cofa': 'أصفر',
#       'jarir_colo': 'أصفر',
#       'media_gallery': [{'type': 'image',
#         'image': '7/8/b/5/78b59a3cca1bd9b252d1a1803e11b7b3d3cbcb8d_585914.jpg',
#         'lab': '',
#         'pos': 0},
#        {'type': 'image',
#         'image': '9/7/3/7/9737775491929940479f2469fa26abe6cc0b296b_585914_1.jpg',
#         'lab': '',
#         'pos': 1},
#        {'type': 'image',
#         'image': 'a/a/c/0/aac01460859af33d30846d3677cc5552bf5b4dae_585914_2.jpg',
#         'lab': '',
#         'pos': 2},
#        {'type': 'image',
#         'image': '5/e/f/9/5ef9b87703014d1aaceebaf36bce4fb7ab5239af_585914_3.jpg',
#         'lab': '',
#         'pos': 3}],
#       'id': 552444,
#       'stock': {'is_in_stock': False,
#        'min_qty': 0,
#        'notify_stock_qty': 1,
#        'use_config_notify_stock_qty': True,
#        'qty': 0,
#        'stock_status': 0},
#       'display_button': 'NO_BUTTON'}],
#     'capa_options': [47467, 47665],
#     'colo_options': [65816, 66967, 67962, 68602, 68683],
#     'stock': {'is_in_stock': False, 'stock_status': 0},
#     'jarir_capa_options': 'سعة 128 جيجابايت, 64 GB',
#     'jarir_colo_options': 'اسود, اخضر, بنفسجي,  ابيض, أصفر',
#     'parent_sku': []},
#    'sort': [9223372036854776000]}}]
